# %% [markdown]
# # Como Análise de Dados com Python me ajudou a correr melhor!
# ### Python Nordeste 2022
# ### Marcel Caraciolo  [github.com/corriporai](http://github.com/corriporai)
#
# #### 26 de agosto 2022

# %% [markdown]
# - Coordenador de Sistemas de Bioinformática e Laboratorial de Genética Molecular Avançada no Hospital Israelita Albert Einstein
# - Engenheiro e Mestre em ciência da computação
# - Interessado em gestão de produtos digitais e data science
# - Criador do pacote runpandas , tema desta palestra
# - Montador de legos nas horas vagas e aspirante a maratonista
#
# **Curiosidades:**  *Fui um dos organizadores da primeira PythonNordeste em Fortaleza, 2013!*

# %% [markdown]
# ![](https://files.speakerdeck.com/presentations/b673d2b095a101313c82768fd0aa6b5a/slide_58.jpg)

# %% [markdown]
# ## Corrida de Rua
#
# Uma das práticas esportivas mais populares do mundo. Acessível para todos,  pois é de baixo custo, pois na sua totalidade, é apenas necessário um tênis ideal e roupas adequadas.
#
# Ela faz parte do conjunto de práticas do atletismo, estando presente também na tríade do Triathlon, junto com a natação e o ciclismo.
#
# A corrida de rua é a mais comum entre os corredores, pois permite ser praticado em ruas, avenidas ou locais abertos. Nas distâncias de rua, em competições oficiais ou amadores, variam desde 5km e indo até a de 42km (distância de maratona).
#
# É o segundo esporte mais praticado no país, tendo um crescimento maior que 50% nos últimos anos, segundo o [Sebrae](https://sebraeinteligenciasetorial.com.br/produtos/boletins-de-tendencia/tendencias-do-mercado-de-corridas-de-rua/5b5a1605d0a9751800f2af49).

# %% [markdown]
# ![](https://www.treinus.com.br/blog/wp-content/uploads/2016/02/roupa-para-correr.jpg)

# %% [markdown]
# ## Maratona
#
#
# A maratona é uma das provas de resistência mais famosas.
#
# A distância oficial de uma maratona não é de 42 km, mas de 42,195 km.
#
# O nome “maratona” vem de uma lenda grega. Conta-se que o soldado ateniense Fidípides correu 42 km para anunciar a vitória dos exército de Atenas contra os persas – e morreu de exaustão na sequência.
#
# Nas Olimpíadas, a maratona só entrou como modalidade feminina em 1984. Até então, acreditava-se que as mulheres não tinham capacidade física para provas de resistência. A prova mais longa que as mulheres participavam até este ano era a de 1500 metros. :(
#
# O corredor mais rápido em uma maratona oficial, até hoje, é o queniano Eliud Kipchoge, que completou a maratona de Berlim em **2:01:39**. Já a corredora mais rápida é a queniana Brigit Kosgei, que completou a maratona de Chigago em
# **2:14:04**.

# %% [markdown]
# ![](https://hips.hearstapps.com/assets.runnersworld.co.uk/i/16421/kipchoge_celebrates.jpg)

# %% [markdown]
# ![](https://s2.glbimg.com/nh1ZR9doJy-1tBEfeQV_-QzYgWE=/0x0:5296x3606/984x0/smart/filters:strip_icc()/s.glbimg.com/es/ge/f/original/2019/10/13/2019-10-13t153152z_95287637_rc1b9d5293d0_rtrmadp_3_athletics-chicago.jpg)

# %% [markdown]
# ### Um maratonista de elite corre em média 20-21km/h!!!
# ![](https://qph.cf2.quoracdn.net/main-qimg-c04796080478a016a00a8b22a32c117d-pjlq)

# %% [markdown]
# ## Uma corrida de rua pode gerar mais dados que você pode imaginar...
#
#
# ![](./images/garmin-clock.png)

# %% [markdown]
# ## Fontes de dados
#
# - Relógios com captura de dados (distância, batimento cardíaco, temperatura, tempo percorrido, cadência, pace, etc...)
# - Marcas como Garmin, Polar, Fitbit, Coros, Samsung, Apple Watch, AmazFit, etc.
#
#
# ![](https://i.insider.com/626ff56d86fa90001905fc0f?width=700)

# %% [markdown]
# ## Fontes de dados
#
# - Aplicativos para Smartphones IOS e Android
#
#
# ![](./images/running-apps.jpg)

# %% [markdown]
# ## Como os dados estão estruturados e formatados ?
#
#
# | File Type | Size  (MB) | Licensed Use Only (Proprietary) | Human- Readable | GPS Data | Standardized Biometric Data | Extensible |
# |-----------|------------|---------------------------------|-----------------|----------|-----------------------------|------------|
# | .csv      | 0.004      |                                 |   Yes           |          |                             |            |
# | .fit      | 0.320      |               Yes               |                 |    Yes   |                             |     Yes    |
# | .gpx      | 2.8        |                                 |       Yes       |    Yes   |                             |     Yes    |
# | .tcx      | 4.8        |                                 |       Yes       |    Yes   |                             |     Yes    |
# | .kml      | 5.4        |                                 |       Yes       |    Yes   |                             |     Yes    |

# %% [markdown]
# ### CSV
#
# O formato .csv é o formato menor e o mais básico. Geralmente só vai conter informações sumarizadas do treino como tempo percorrido, pace médio, batimento cardiáco médio, distância total percorrida, etc.  Geralmente não conteém informações das coordenadas do GPS da atividade.
#
#
# `Split","Time","Moving Time","Distance","Elevation Gain","Elev Loss","Avg Pace","Avg Moving Paces","Best Pace","Avg Run Cadence","Max Run Cadence","Avg Stride Length","Avg HR","Max HR","Avg Temperature","Calories"
# "1","02:54:17    ","02:54:01    ","21.94","800","801","00:07:57    ","00:07:56    ","00:00:00    ","81","105","92","--","--","21","113"
# "Summary","02:54:17    ","02:54:01    ","21.94","800","801","00:07:57    ","00:07:56    ","00:00:00    ","81","105","88","--","--","21","113"`

# %% [markdown]
# ### FIT (Flexible and Interoperable data Transfer)
#
# O formato .fit é um formato proprietário e desenvolvido pela Garmin e não são human-readable. Eles são codificados e precisa de um parser .fit para extração de dados.  Como proprietário você precisa estar de acordo com as licenças da Garmin. Há várias bibliotecas que já decodificam o arquivo .fit. O grande problema dos arquivos .fit é por ser proprietário, eles podem fechar o ecossistema a qualquer momento. O Garmin considera este formato o padrão entre os seus dispositivos.
#
# Uma das principais vantagens do arquifo FIT é a quantidade de informações que podem ser codificadas dentro do formato e a compactação do mesmo.

# %% [markdown]
# ![](https://miro.medium.com/max/1400/1*f3p9uMgX0q4WPaSkCRom5A.png)

# %% [markdown]
# ![](https://miro.medium.com/max/1400/1*U8qAbP32iKjmi2snOU25Ug.png)

# %% [markdown]
# ### TCX (Training Center XML)
#
# TCX é um outro formato escrito em XML desenvolvido pela Garmin. Ele foi criado com o objetico de extender as capacidades do GPX (que era focado em apenas dados de GPS), adicionando novos tipos de dados como frequência de batimento cardiaco, cadencia e outros dados esportivos. Ele é open-source e mantido pela Garmin.
#
#
# ![](./images/tcx_example.png)

# %% [markdown]
# ### GPX (GPS Exchange Format)
#
# GPX é um dos formatos mais antigos e tradicionais para intercâmbio de dados de GPS.  GPX é um formato via XML e amplamente usado em vários dispositivos e social apps. Embora sua especificação tenha dado início com o foco em GPS track points (coordenadas GPS com timestamps), as *extensions* foram criadas para permitir sua extensão. Atualmente já é possíve ter dados de cadência, batimento cardiaco, temperatura, etc.
#
# ![](./images/gpx_example.png)

# %% [markdown]
# ### KML (Keyhold Markup Language)
#
# KML foi criado para visualização de dados geográficos a partir de um browser específico como o Google Earth. Ele contém informações de timestamp e coordenadas GPS. Ele não é orientado a dados esportivos, portanto sua especificação não detalha como registrar dados biométricos, embora seja tecnicamente possível.
#
# O seu uso hoje é mais para visualização das rotas dos percursos em cima de uma interface como o Google Maps/Google Earth. É o menos usado para regisro de métricas esportivas.
#
# ![](./images/km_example.png)

# %% [markdown]
# ## E como os social Apps trabalham ?
#
# Além de exportar em um ou mais formatos apresentados acima, vários dos apps possuem APIs públicas (ou não) para desenvolvedores que podem consumir e coletar seu histórico de atividades.
#
# - Strava (https://developers.strava.com/)
# - Nike Run Club (https://github.com/yasoob/nrc-exporter)
# - RunStatic (https://help.runtastic.com/hc/en-us/articles/360008124939-Export-Account-Data)
#
# <img src="https://i.ytimg.com/vi/1Z9-cnGZ9ew/maxresdefault.jpg" alt="Drawing" style="width: 800px;"/>

# %% [markdown]
# ## Quais as métricas que podemos extrair destes dados ?
#
# ![](./images/nike_run.jpg)

# %% [markdown]
# ### Vamos falar de algumas!

# %% [markdown]
# ### Distância Pecorrida (distance)
#
# - Distância pecorrida em metros, km ou milhas do ponto de início até o fim da sua corrida.
# <div style="float: left; width: 60%;">
# <img src="./images/haversine.png" alt="Drawing" style="width: 600px;"/>
# </div>
# <div style="float: right; width: 40%;">
# <img src="./images/latlong.png" alt="Drawing" style="width: 800px;">
# </div>

# %% [markdown]
# ### Tempo Pecorrido x Tempo em Movimento  (ellapsed time x moving time)
# - Tempo total percorrido significa o tempo em horas:minutos:segundos do momento que o atleta iniciou o registro até o seu término. Já o Tempo em Movimento define o tempo em que o atleta de fato estava em movimento. Este tempo é usualmente utilizado para os cálculos do pace e de splits. Cada aplicativo/dispositivo define sua fórmula de determinar um atleta em movimento.
# <div style="float: left; width: 60%;">
# <img src="./images/average_pace.jpeg" alt="Drawing" style="width: 600px;"/>
# </div>
# <div style="float: right; width: 40%;">
# <img src="./images/auto-pause.png" alt="Drawing" style="width: 800px;">
# </div>

# %% [markdown]
# ###  Velocidade Média x Pace Médio (avg speed x avg pace)
# - Velocidade é a distância percorrida em um determinado tempo, como por exemplo, número de metros no tempo de 1 segundo (m/s), ou número de kms no tempo de 1 hora (km/h).
# - Pace é o montante de tempo necessário para cobrir uma distância específica, como por exemplo, números de minutos para cobrir 1km. A métrica de pace é muito utilizada nos planilhas de treinamento para seus objetivos de corrida.
#
# `Speed(km/h)  = distance(km) / time(h)     Pace (min/km) = time (min) / distance (km)`
#
# <div style="float: left; width: 40%;">
#
# <img src="./images/average_pace.jpeg" alt="Drawing" style="width: 400px;">
# </div>
#
# <div style="float: right; width: 49%;">
#
# <img src="./images/running-pace-calculator.png" alt="Drawing" style="width: 500px;">
# </div>

# %% [markdown]
# <center>
#
# <img src="./images/mypace.png" alt="Drawing" style="width: 400px;">
# </center>
#
# https://www.omnicalculator.com/sports/pace

# %% [markdown]
# ###  Cadência (cad)
# - Cadência é uma métrica que informa quantos passos você deu em um determinado período, geralmente é mensurado como passos por minuto.
#
# <div style="float: left; width: 40%;">
#
# <img src="./images/cadence2.jpeg" alt="Drawing" style="width: 500px;">
# </div>
#
# <div style="float: right; width: 49%;">
#
# <img src="./images/cadence-plot.png" alt="Drawing" style="width: 800px;">
# </div>

# %% [markdown]
# ### Ganho de Elevação e gradiente (ele) (grad)
#
# - **Ganho / perda de elevação** : o primeiro valor, positivo, indica o ganho acumulado de elevação desde o começo do caminho. A palavra 'acumulado' significa que todas as elevações são somadas, ou seja, se você subiu 100m, desceu 100m e subiu 150m, o ganho de elevação foi de 250m, e não de 50m. É uma medida que reflete quanto o corredor precisará subir para vencer um circuito, quer seja numa corrida, num treinamento ou num passeio.
# - **Gradiente**: É  resultado do total de ganho altimétrico dividido pela distância percorrida. Em outras palavras, se você subiu 100 metros em um total de 1km (ou mil metros), então o grau é de 10% (100/1.000). Simples assim.
#
# <div style="float: left; width: 40%;">
#
# <img src="./images/gradient.jpeg" alt="Drawing" style="width: 500px;"/>
# </div>
#
# <div style="float: right; width: 49%;">
#
# <img src="./images/elevationgain.png" alt="Drawing" style="width: 300px;"/>
# </div>

# %% [markdown]
# <img src="./images/altimetria-21k.jpeg" alt="Drawing" style="width: 700px;"/>

# %% [markdown]
# ### Frequência Cardíaca (HR)
#
# A frequência cardíaca é uma métrica nas corridas que define a quantidade de batimentos cardiácos em um determinado período. Geralmente é definido por batimentos por minuto (bpm). Ela é uma ferramenta útil se você quiser saber mais sobre seu desempenho esportivo. Ao treinar medindo a frequência cardíaca, você pode monitorar e controlar a intensidade de seus treinos.
#
# <div style="float: left; width: 40%;">
#
# <img src="./images/heart-rate.png" alt="Drawing" style="width: 600px;"/>
# </div>
#
# <div style="float: right; width: 49%;">
#
# <img src="./images/hr-watch.png" alt="Drawing" style="width: 400px;"/>
# </div>

# %% [markdown]
# ### E muito mais métricas!
#
# <div></div>
#
#
# <center>
# <img src="./images/wordcloud.png" alt="Drawing" style="width: 600px;"/>
# </center>

# %% [markdown]
# ## Quais são as alternativas para capturar , extrair e analisar estes dados ?
#
# - Soluções artesanais usando Python, R, Scala, Rust, etc.
# - Algumas libs disponíveis como [SweatPy](https://github.com/GoldenCheetah/sweatpy) ou [TrackeR](https://cran.r-project.org/web/packages/trackeR/vignettes/trackeR.pdf)
# - Bibliotecas especializadas em extrair do Strava ou ler arquivos GPX, TCX, etc.

# %% [markdown]
# ## O que vamos apresentar ?
#
#
# <center>
# <img src="./images/runpandas_03.png" alt="Drawing" style="width: 400px;"/>
# </center>

# %% [markdown]
# ## Runpandas
#
#
# <div style="float: left; width: 49%;">
#
# - Biblioteca baseada em Python e Pandas para análise de dados de atividades de corrida.
#
# - Construído em meados de 2021.
#
# - Versão 0.5
#
# - Open-Source e Licença MIT.
#
# - Diretamente de Pernambuco, Brasil para o mundo.
#
# - https://www.runpandas.run/en/latest/
#
# </div><div style="float: right; width: 49%;">
#
#  !["Image"](images/runpandas_11.png)
#
# </div>

# %% [markdown]
# ### Runpandas Basics

# %% [markdown]
# #### Ter pelo menos 1 dispositivo (relógio ou app) que exporta arquivos de tracking.
#
#
# ![](./images/export-devices.png)

# %% [markdown]
# #### Um exemplo
# https://gist.github.com/marcelcaraciolo/29c30fa2b46a9b86dcad5f01b345427c
# ![](./images/tcx_sample.png)

# %% [markdown]
# ### Extraindo dados com uma simples atividade

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install runpandas
import runpandas as rpd

# %%
activity = rpd.read_file('./basics/sample.tcx')

# %%
activity.head(5)
# Out:
#                         alt       dist  hr        lon        lat
# time
# 0 days 00:00:00  178.942627   0.000000  62 -79.093187  35.951880
# 0 days 00:00:01  178.942627   0.000000  62 -79.093184  35.951880
# 0 days 00:00:06  178.942627   1.106947  62 -79.093172  35.951868
# 0 days 00:00:12  177.500610  13.003035  62 -79.093228  35.951774
# 0 days 00:00:16  177.500610  22.405027  60 -79.093141  35.951732

# %%
print (type(activity))
print(type(activity.alt))
# Out:
# <class 'runpandas.types.frame.Activity'>
# <class 'runpandas.types.columns.Altitude'>

# %%
print(activity.alt.base_unit)
print(activity.alt.sum())
# Out:
# m
# 65883.68151855901

# %%
print(activity.dist.base_unit)
print(activity.dist[-1])
# Out:
# m
# 4686.31103516

# %%
#total time elapsed for the activity
print(activity.ellapsed_time)
#distance of workout in meters
print(activity.distance)
#mean heartrate
print(activity.mean_heart_rate())
# Out:
# 0 days 00:33:11
# 4686.31103516
# 156.65274151436032

# %%
#compute the distance using haversine formula between two consecutive latitude, longitudes observations.
activity['distpos']  = activity.compute.distance()
activity['distpos'].head()
# Out:
# time
# 0 days 00:00:00          NaN
# 0 days 00:00:01     0.333146
# 0 days 00:00:06     1.678792
# 0 days 00:00:12    11.639901
# 0 days 00:00:16     9.183847
# Name: distpos, dtype: float64

# %%
#compute the distance using haversine formula between two consecutive latitude, longitudes observations.
activity['speed']  = activity.compute.speed(from_distances=True)
activity['speed'].head()
# Out:
# time
# 0 days 00:00:00         NaN
# 0 days 00:00:01    0.333146
# 0 days 00:00:06    0.335758
# 0 days 00:00:12    1.939984
# 0 days 00:00:16    2.295962
# Name: speed, dtype: float64

# %%
activity['vam'] = activity.compute.vertical_speed()
activity['vam'].head()
# Out:
# time
# 0 days 00:00:00         NaN
# 0 days 00:00:01    0.000000
# 0 days 00:00:06    0.000000
# 0 days 00:00:12   -0.240336
# 0 days 00:00:16    0.000000
# Name: vam, dtype: float64

# %%
#To compute the moving time, there is a special acessor that detects the periods of inactivity
#  and returns the moving series containing all the observations considered to be stopped.

activity_only_moving = activity.only_moving()
print(activity_only_moving['moving'].head())
# Out:
# time
# 0 days 00:00:00    False
# 0 days 00:00:01    False
# 0 days 00:00:06    False
# 0 days 00:00:12     True
# 0 days 00:00:16     True
# Name: moving, dtype: bool

# %%
activity_only_moving.moving_time
# Out:
# Timedelta('0 days 00:33:05')

# %%
activity[['dist']].plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
activity[['alt']].plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
activity.plot.scatter(x='dist', y='alt', c='DarkBlue')
# Out:
# <AxesSubplot:xlabel='dist', ylabel='alt'>

# %%
activity.plot(x='lon', y='lat')
# Out:
# <AxesSubplot:xlabel='lon'>

# %%
import gmplot

#let's get the min/max latitude and longitudes
min_lat, max_lat, min_lon, max_lon = \
min(activity['lat']), max(activity['lat']), \
min(activity['lon']), max(activity['lon'])

## Create empty map with zoom level 16
mymap = gmplot.GoogleMapPlotter(
    min_lat + (max_lat - min_lat) / 2,
    min_lon + (max_lon - min_lon) / 2,
    16, apikey='API-KEY')
#To plot the data as a continuous line (or a polygon), we can use the plot method. It has two self-explanatory optional arguments: color and edge width.
mymap.plot(activity['lat'], activity['lon'], 'blue', edge_width=1)

#Draw the map to an HTML file.
mymap.draw('myroute.html')

# %%
#Show the map (here I saved the myroute.html as image for the illustration purposes)
import IPython
IPython.display.Image(filename='images/myroute.png')

# %% [markdown]
# ### Runpandas Advanced
#
# - Permitir a análise de corridas em conjunto.
# - Introduzindo o conceito de sessões.
#
#
# ![](./images/session.png)

# %% [markdown]
# ### Session por trás dos panos...
# https://pandas.pydata.org/docs/user_guide/advanced.html
#
#  !["Image"](https://jessicastringham.net/assets/2019-12-10-multiindex-input.png)

# %% [markdown]
# #### Runpandas Advanced

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import runpandas as rpd
activity = rpd.read_file('./basics/sample.tcx')

# %%
#compute the common metrics for the running activity such as distance per position, speed, pace, etc.
activity['distpos']  = activity.compute.distance()
activity['speed']  = activity.compute.speed(from_distances=True)
activity['vam'] = activity.compute.vertical_speed()
activity_only_moving = activity.only_moving()

# %%
activity_only_moving.summary()
# Out:
# Session                           Running: 26-12-2012 21:29:53
# Total distance (meters)                            4686.311035
# Total ellapsed time                            0 days 00:33:11
# Total moving time                              0 days 00:33:05
# Average speed (km/h)                                  8.476556
# Average moving speed (km/h)                           8.498529
# Average pace (per 1 km)                        0 days 00:07:04
# Average pace moving (per 1 km)                 0 days 00:07:03
# Average cadence                                            NaN
# Average moving cadence                                     NaN
# Average heart rate                                  156.652742
# Average moving heart rate                                157.4
# Average temperature                                        NaN
# dtype: object

# %%
import runpandas
session = runpandas.read_dir_aggregate(dirname='advanced/session/')

# %%
session
# Out:
#                                                      alt     hr        lon  \
# start                   time
# 2020-08-30 09:08:51.012 0 days 00:00:00              NaN    NaN -34.893609
#                         0 days 00:00:01.091000       NaN    NaN -34.893624
#                         0 days 00:00:02.091000       NaN    NaN -34.893641
#                         0 days 00:00:03.098000       NaN    NaN -34.893655
#                         0 days 00:00:04.098000       NaN    NaN -34.893655
# ...                                                  ...    ...        ...
# 2021-07-04 11:23:19.418 0 days 00:52:39.582000  0.050001  189.0 -34.894534
#                         0 days 00:52:43.582000       NaN    NaN -34.894465
#                         0 days 00:52:44.582000       NaN    NaN -34.894443
#                         0 days 00:52:45.582000       NaN    NaN -34.894429
#                         0 days 00:52:49.582000       NaN  190.0 -34.894395
#
# ...

# %%
session.index  #MultiIndex (start, timestamp)
# Out:
# MultiIndex([('2020-08-30 09:08:51.012000',        '0 days 00:00:00'),
#             ('2020-08-30 09:08:51.012000', '0 days 00:00:01.091000'),
#             ('2020-08-30 09:08:51.012000', '0 days 00:00:02.091000'),
#             ('2020-08-30 09:08:51.012000', '0 days 00:00:03.098000'),
#             ('2020-08-30 09:08:51.012000', '0 days 00:00:04.098000'),
#             ('2020-08-30 09:08:51.012000', '0 days 00:00:05.096000'),
#             ('2020-08-30 09:08:51.012000', '0 days 00:00:06.096000'),
#             ('2020-08-30 09:08:51.012000', '0 days 00:00:07.097000'),
#             ('2020-08-30 09:08:51.012000', '0 days 00:00:08.097000'),
#             ('2020-08-30 09:08:51.012000', '0 days 00:00:09.102000'),
#             ...
#             ('2021-07-04 11:23:19.418000', '0 days 00:52:18.584000'),
#             ('2021-07-04 11:23:19.418000', '0 days 00:52:22.584000'),
#             ('2021-07-04 11:23:19.418000', '0 days 00:52:26.582000'),
# ...

# %%
#count the number of activities in the session
print ('Total Activities:', session.session.count())
# Out:
# Total Activities: 68

# %%
#In this example we compute the distance and the distance per position across all workouts
session = session.session.distance()
session
# Out:
#                                                      alt     hr        lon  \
# start                   time
# 2020-08-30 09:08:51.012 0 days 00:00:00              NaN    NaN -34.893609
#                         0 days 00:00:01.091000       NaN    NaN -34.893624
#                         0 days 00:00:02.091000       NaN    NaN -34.893641
#                         0 days 00:00:03.098000       NaN    NaN -34.893655
#                         0 days 00:00:04.098000       NaN    NaN -34.893655
# ...                                                  ...    ...        ...
# 2021-07-04 11:23:19.418 0 days 00:52:39.582000  0.050001  189.0 -34.894534
#                         0 days 00:52:43.582000       NaN    NaN -34.894465
#                         0 days 00:52:44.582000       NaN    NaN -34.894443
#                         0 days 00:52:45.582000       NaN    NaN -34.894429
#                         0 days 00:52:49.582000       NaN  190.0 -34.894395
#
# ...

# %%
#comput the speed for each activity
session = session.session.speed(from_distances=True)
#compute the pace for each activity
session = session.session.pace()
#compute the inactivity periods for each activity
session = session.session.only_moving()

# %%
session
# Out:
#                                                      alt     hr        lon  \
# start                   time
# 2020-08-30 09:08:51.012 0 days 00:00:00              NaN    NaN -34.893609
#                         0 days 00:00:01.091000       NaN    NaN -34.893624
#                         0 days 00:00:02.091000       NaN    NaN -34.893641
#                         0 days 00:00:03.098000       NaN    NaN -34.893655
#                         0 days 00:00:04.098000       NaN    NaN -34.893655
# ...                                                  ...    ...        ...
# 2021-07-04 11:23:19.418 0 days 00:52:39.582000  0.050001  189.0 -34.894534
#                         0 days 00:52:43.582000       NaN    NaN -34.894465
#                         0 days 00:52:44.582000       NaN    NaN -34.894443
#                         0 days 00:52:45.582000       NaN    NaN -34.894429
#                         0 days 00:52:49.582000       NaN  190.0 -34.894395
#
# ...

# %%
summary = session.session.summarize()
summary
# Out:
#                                       moving_time  mean_speed  max_speed  \
# start
# 2020-07-03 09:50:53.162    0 days 00:25:29.838000    2.642051   4.879655
# 2020-07-05 09:33:20.999 0 days 00:05:04.998999999    2.227637   6.998021
# 2020-07-05 09:41:59.999           0 days 00:18:19    1.918949   6.563570
# 2020-07-13 09:13:58.718    0 days 00:40:21.281000    2.509703   8.520387
# 2020-07-17 09:33:02.308    0 days 00:32:07.691000    2.643278   8.365431
# ...                                           ...         ...        ...
# 2021-06-13 09:22:30.985    0 days 01:32:33.018000    2.612872  23.583956
# 2021-06-20 09:16:55.163 0 days 00:59:44.511999999    2.492640   6.065895
# 2021-06-23 09:37:44.000    0 days 00:26:49.001000    2.501796   5.641343
# 2021-06-27 09:50:08.664    0 days 00:31:42.336000    2.646493  32.734124
# 2021-07-04 11:23:19.418 0 days 00:47:47.582999999    2.602263   4.212320
#
#                               mean_pace        max_pace  mean_moving_speed  \
# ...

# %%
print('Session Interval:', (summary.index.to_series().max() - summary.index.to_series().min()).days, 'days')
print('Total Workouts:', len(summary), 'runnings')
print('Tota KM Distance:', summary['total_distance'].sum() / 1000)
print('Average Pace (all runs):', summary.mean_pace.mean())
print('Average Moving Pace (all runs):', summary.mean_moving_pace.mean())
print('Average KM Distance (all runs):', round(summary.total_distance.mean()/ 1000,2))
# Out:
# Session Interval: 366 days
# Total Workouts: 68 runnings
# Tota KM Distance: 491.77377537338896
# Average Pace (all runs): 0 days 00:07:18.397058823
# Average Moving Pace (all runs): 0 days 00:06:02.147058823
# Average KM Distance (all runs): 7.23

# %% [markdown]
# ### Reading from Strava
#
# - Já possuímos integração com alguns social apps, como o Strava e Nike Run.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import runpandas
client = runpandas.StravaClient(token_file='./token.json')

# %%
activity = runpandas.read_strava('7329257123')
activity.summary()
# Out:
# Unable to set attribute media_type on entity <ActivityPhotoPrimary id=None>
# /opt/miniconda3/envs/runpandas_ppt/lib/python3.8/site-packages/runpandas/types/frame.py:64: UserWarning: The specified key watts not found.
#   warnings.warn("The specified key %s not found." % old_key, UserWarning)
# Session                           Running: 18-06-2022 07:08:07
# Total distance (meters)                                21389.8
# Total ellapsed time                            0 days 02:02:20
# Total moving time                              0 days 02:02:19
# Average speed (km/h)                                       NaN
# Average moving speed (km/h)                                NaN
# Average pace (per 1 km)                                    NaN
# Average pace moving (per 1 km)                             NaN
# Average cadence                                      87.788852
# Average moving cadence                               87.847012
# ...

# %% [markdown]
# ## Analisando meu histórico de corrida
#
#
# - Comecei a correr em abril de 2018. Mas só fui registrar em relógio em meados do fim de 2018.
# - Comecei a correr por conta própria.
# - Esse era eu abaixo aos 34 anos com 90kg...

# %% [markdown]
# <img src="./images/marcel_2018.jpeg" alt="Drawing" style="width: 700px;"/>

# %% [markdown]
# ## Ano 2018: Apenas um hobby
#
# <div style="float: left; width: 49%;">
#
# - Corria por conta própria, sem nenhum acompanhamento.
#
# - Planilhas mentais.
#
# - Treinos de 1 a 2x por semana.
#
# </div><div style="float: right; width: 30%;">
#
# <img src="./images/marcel-run-2018.JPG" alt="Drawing" style="width: 600px;"/>
#
# Corrida Circuito das Estações  Verão 2018 - meus primeiros 5km
# </div>

# %%
import warnings
warnings.filterwarnings('ignore')
import runpandas as rpd

# %%
import altair as alt
alt.renderers.enable('default')
# Out:
# RendererRegistry.enable('default')

# %%
session = rpd.read_dir_aggregate('./marcel_runs/2018')
#In this session we compute the distance and the distance per position across all workouts
session = session.session.distance()
#comput the speed for each activity
session = session.session.speed(from_distances=True)
#compute the pace for each activity
session = session.session.pace()
#compute the inactivity periods for each activity
session = session.session.only_moving()
session
# Out:
#                                             alt     hr        lon       lat  \
# start                     time
# 2018-12-16 10:30:46+00:00 0 days 00:00:00  14.6  131.0 -34.903926 -8.036597
#                           0 days 00:00:09  14.4  131.0 -34.904030 -8.036444
#                           0 days 00:00:11  14.4  131.0 -34.904064 -8.036397
#                           0 days 00:00:14  14.3  131.0 -34.904110 -8.036319
#                           0 days 00:00:16  14.3  131.0 -34.904153 -8.036264
# ...                                         ...    ...        ...       ...
# 2018-09-16 10:12:52+00:00 0 days 00:32:46   6.7  181.0 -34.895710 -8.084540
#                           0 days 00:32:49   6.5  181.0 -34.895752 -8.084571
#                           0 days 00:32:51   6.4  181.0 -34.895791 -8.084600
#                           0 days 00:32:54   6.2  181.0 -34.895832 -8.084662
#                           0 days 00:32:56   6.0  181.0 -34.895865 -8.084700
#
# ...

# %%
summary = session.session.summarize()
summary
# Out:
#                               moving_time  mean_speed  max_speed  \
# start
# 2018-09-16 10:12:52+00:00 0 days 00:32:54    2.619146   4.272546
# 2018-09-23 12:14:33+00:00 0 days 01:17:12    2.103118  13.799073
# 2018-09-30 13:43:05+00:00 0 days 01:18:28    2.075842   5.659931
# 2018-10-07 12:44:26+00:00 0 days 01:14:18    2.063746  10.952164
# 2018-10-13 11:54:15+00:00 0 days 01:08:24    2.067841   6.630504
# 2018-10-21 17:02:57+00:00 0 days 00:47:01    2.103396   5.044153
# 2018-10-29 22:26:09+00:00 0 days 01:11:31    2.365415   7.722322
# 2018-11-11 10:05:28+00:00 0 days 01:07:59    2.400343  15.070331
# 2018-11-18 11:04:34+00:00 0 days 01:14:33    2.277504   6.278804
# 2018-11-25 11:37:34+00:00 0 days 00:55:35    2.056357   9.540053
# 2018-11-30 09:12:22+00:00 0 days 00:33:51    2.513163   8.420132
# 2018-12-09 09:40:12+00:00 0 days 00:32:29    2.565170   9.661220
# 2018-12-13 23:29:40+00:00 0 days 00:35:01    2.311177  10.326621
# ...

# %%
summary['days_diff'] = summary.index.to_series().diff().dt.days
summary['total_distance'] = summary['total_distance'] / 1000  #conver meters to kms
summary['mean_speed'] = summary['mean_speed'] * 3.6 #convert to km/h

# %%
import pandas as pd
summary = summary.assign(Year=summary.index.year, Month=summary.index.month, Week=summary.index.week, Weekday=summary.index.weekday)
summary['Year-month'] = pd.to_datetime(summary[['Year','Month']].assign(day=1)).dt.to_period('M')
summary['Year-week'] =  summary.index.strftime('%Y-w%U')
summary
# Out:
#                               moving_time  mean_speed  max_speed  \
# start
# 2018-09-16 10:12:52+00:00 0 days 00:32:54    9.428926   4.272546
# 2018-09-23 12:14:33+00:00 0 days 01:17:12    7.571226  13.799073
# 2018-09-30 13:43:05+00:00 0 days 01:18:28    7.473030   5.659931
# 2018-10-07 12:44:26+00:00 0 days 01:14:18    7.429485  10.952164
# 2018-10-13 11:54:15+00:00 0 days 01:08:24    7.444227   6.630504
# 2018-10-21 17:02:57+00:00 0 days 00:47:01    7.572226   5.044153
# 2018-10-29 22:26:09+00:00 0 days 01:11:31    8.515493   7.722322
# 2018-11-11 10:05:28+00:00 0 days 01:07:59    8.641235  15.070331
# 2018-11-18 11:04:34+00:00 0 days 01:14:33    8.199013   6.278804
# 2018-11-25 11:37:34+00:00 0 days 00:55:35    7.402886   9.540053
# 2018-11-30 09:12:22+00:00 0 days 00:33:51    9.047387   8.420132
# 2018-12-09 09:40:12+00:00 0 days 00:32:29    9.234612   9.661220
# 2018-12-13 23:29:40+00:00 0 days 00:35:01    8.320237  10.326621
# ...

# %%
import matplotlib.pyplot as plt
fig, axr = plt.subplots(1,3 ,figsize=(60,20 ))

ticks = summary.groupby(summary['Year-month']).agg({'total_distance': 'sum'}).index.astype('str').to_list()


axr[0].bar(summary.groupby(summary['Year-month']).agg({'total_distance': 'sum'}).index.astype('str'), 
            summary.groupby(summary['Year-month']).agg({'total_distance': 'sum'}).values.flatten(),
        yerr=summary.groupby(summary['Year-month']).agg({'total_distance': 'std'}).values.flatten(),
        tick_label=ticks, label='Number of kilometers')
axr[0].set_title('Total number of kilometers')
axr[0].set_ylabel('Km')
summary.boxplot(['mean_speed'], by='Year-month', ax=axr[1])
axr[1].set_xticklabels(ticks)
axr[1].set_ylabel('Km/h')
summary.groupby('Year-month')['mean_speed'].count().plot.bar(ax=axr[2], color='C1')
axr[2].set_xticklabels(ticks)
axr[2].set_title('Number of trainings')
plt.show()

# %% [markdown]
# ### Pergunta chave ? Durante 2018 , consegui evoluir ?

# %%
#let's convert the pace to float number in minutes
import datetime
summary['mean_moving_pace_float'] = summary['mean_moving_pace'] / datetime.timedelta(minutes=1)

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np

plt.subplots(figsize=(30, 10))

plt.plot(summary.index, summary.mean_moving_pace_float, color='silver', label = 'average pace')


#add trend line
x = np.asarray(summary.index)  #convert data to numpy array
x2 = mdates.date2num(x)
y = np.asarray(summary.mean_moving_pace_float)
z=np.polyfit(x2,y,1)
p=np.poly1d(z)
plt.plot(x,p(x2),'r--')
#format the figure and display
fig.autofmt_xdate(rotation=45)
fig.tight_layout()
fig.show()
plt.title("Pace Evolution")
plt.xlabel("Runnings")
plt.ylabel("Pace")
plt.legend()

# %% [markdown]
# ### De fato foi um ano positivo, mas precisava evoluir mais...
#
# - Treinar sozinho aumenta risco de lesões se você levar a corrida a sério.
#
# - Começa a estacionar sem evoluções em tempo x distância.
#
# -  Atingir maiores objetivos, maior distância tinha sido um 10km.

# %% [markdown]
# ![Images](./images/Artigos-Corrida.png)

# %% [markdown]
# ## Ano 2019: Caso de Amor com a Corrida
#
# <div style="float: left; width: 49%;">
#
# - Personal trainer para fortalecimento da musculatura.
#
# - Planilhas por whatsApp.
#
# - Continuam treinos 1 a 2 x semana.
#
# - Missão: Completar minha primeira meia maratona.
#
# </div><div style="float: right; width: 30%;">
#
# <img src="./images/BB-Run.png" alt="Corrida dos circuito do Banco do Brasil 2019
# " style="width: 600px;"/>
#
# Corrida dos circuito do Banco do Brasil 2019
#
# </div>

# %%
session = rpd.read_dir_aggregate('./marcel_runs/2019')
#In this session we compute the distance and the distance per position across all workouts
session = session.session.distance()
#compute the speed for each activity
session = session.session.speed(from_distances=True)
#compute the pace for each activity
session = session.session.pace()
#compute the inactivity periods for each activity
session = session.session.only_moving()
summary = session.session.summarize()
summary
# Out:
#                               moving_time  mean_speed  max_speed  \
# start
# 2019-01-06 10:27:21+00:00 0 days 00:33:49    2.594635  33.473246
# 2019-01-20 11:30:58+00:00 0 days 00:32:13    2.452365  16.681533
# 2019-01-27 08:57:38+00:00 0 days 01:10:58    2.378023   4.985082
# 2019-02-03 11:58:15+00:00 0 days 00:30:54    2.265202   6.985967
# 2019-02-10 09:40:58+00:00 0 days 00:31:28    2.817892   4.015752
# 2019-02-14 23:07:31+00:00 0 days 00:13:08    2.367958   4.339125
# 2019-02-17 11:09:27+00:00 0 days 00:37:23    2.059945   7.217845
# 2019-03-02 10:43:22+00:00 0 days 00:32:13    2.339936  11.460783
# 2019-03-10 11:22:02+00:00 0 days 00:27:17    8.039794  43.799204
# 2019-03-15 23:20:10+00:00 0 days 00:31:28    1.862493  16.031725
# 2019-03-17 11:51:34+00:00 0 days 00:55:25    2.366787   7.507723
# 2019-03-24 09:59:09+00:00 0 days 00:32:43    2.020862   3.893382
# 2019-04-14 10:05:22+00:00 0 days 01:12:52    2.270226   4.887443
# ...

# %%
summary['days_diff'] = summary.index.to_series().diff().dt.days
summary['total_distance_km'] = summary['total_distance'] / 1000  #conver meters to kms
summary['mean_speed_km'] = summary['mean_speed'] * 3.6 #convert to km/h
summary = summary.assign(Year=summary.index.year, Month=summary.index.month, Week=summary.index.week, Weekday=summary.index.weekday)
summary['Year-month'] = pd.to_datetime(summary[['Year','Month']].assign(day=1)).dt.to_period('M')
summary['Year-week'] =  summary.index.strftime('%Y-w%U')

# %%
### Brincando com Altair

# altair setup
import altair as alt
import datetime
alt.renderers.enable('default')


runs = summary[['Year', 'Year-month', 'Year-week', 'total_distance_km', 'mean_speed_km', 'mean_pace']].copy()
runs['Year-month'] = runs['Year-month'].astype(str)
runs['Year-week'] =   runs['Year-week'].astype(str)

def convert_to_minutes(time_delta_obj):
    return time_delta_obj/datetime.timedelta(minutes=1)

runs['mean_pace_float'] = runs['mean_pace'].apply(convert_to_minutes)


runs
# Out:
#                            Year Year-month Year-week  total_distance_km  \
# start
# 2019-01-06 10:27:21+00:00  2019    2019-01  2019-w01           5.822360
# 2019-01-20 11:30:58+00:00  2019    2019-01  2019-w03           5.275038
# 2019-01-27 08:57:38+00:00  2019    2019-01  2019-w04          10.147025
# 2019-02-03 11:58:15+00:00  2019    2019-02  2019-w05           4.537200
# 2019-02-10 09:40:58+00:00  2019    2019-02  2019-w06           5.320180
# 2019-02-14 23:07:31+00:00  2019    2019-02  2019-w06           1.889630
# 2019-02-17 11:09:27+00:00  2019    2019-02  2019-w07           4.902670
# 2019-03-02 10:43:22+00:00  2019    2019-03  2019-w08           5.042561
# 2019-03-10 11:22:02+00:00  2019    2019-03  2019-w10          14.246515
# 2019-03-15 23:20:10+00:00  2019    2019-03  2019-w10           4.008085
# 2019-03-17 11:51:34+00:00  2019    2019-03  2019-w11           8.030509
# 2019-03-24 09:59:09+00:00  2019    2019-03  2019-w12           4.162976
# ...

# %%
# the dataframe for annotations

labels = (
    alt.Chart(
        runs
        .groupby("Year-month")
        .agg(
            label = ("total_distance_km", "count")
        )
        .assign(
            y = lambda x: x.label + 2
        )
        .reset_index()
    )
    .mark_text()
    .encode(
        x = "Year-month:O",
        y = "y",
        text = "label"
    )
)


# the chart
chart = (
    alt.Chart(runs)
    .mark_bar()
    .encode(
        alt.X("Year-month:O", bin = False, title = "months running"),
        alt.Y(aggregate = "count", type = "quantitative", title = "number of runs")
    )
    #.mark_text
    .properties(
        title = "Numbers of trainings in 2019",
        width = 900,
        height = 500
    )
)


chart2 = (alt.Chart(runs).mark_boxplot(size=40).encode(
    x='Year-month:O',
    y=alt.Y('mean_speed_km:Q',scale=alt.Scale(zero=False)),
).properties(width=900, height=500, title='Average speed in 2019')
)


labels3 = (
    alt.Chart(
        runs
        .groupby("Year-month")
        .agg(
            label = ("total_distance_km", "sum")
        )
        .assign(
            y = lambda x: x.label + 2
        )
        .reset_index()
    )
    .mark_text()
    .encode(
        x = "Year-month:O",
        y = "y",
        text = "label"
    )
)


# the chart
chart3 = (
    alt.Chart(runs)
    .mark_bar()
    .encode(
        alt.X("Year-month:O", bin = False, title = "months running"),
        alt.Y(aggregate = "sum", field='total_distance_km',  type = "quantitative", title = "Total Distance")
    )
    #.mark_text
    .properties(
        title = "Total distance through in 2019",
        width = 900,
        height = 500
    )
)


# combine chart and label
chart3 + labels3 |chart2 | chart + labels
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# - Mais frequência nos treinos (a partir do segundo semestre), maiores distâncias.
#
# ![](./images/altair.png)

# %%
labels = (
    alt.Chart(
        runs
        .groupby("Year-week")
        .agg(
            label = ("total_distance_km", "count")
        )
        .assign(
            y = lambda x: x.label + 2
        )
        .reset_index()
    )
    .mark_text()
    .encode(
        x = "Year-week:O",
        y = "y",
        text = "label"
    )
)


# the chart
chart = (
    alt.Chart(runs)
    .mark_bar()
    .encode(
        alt.X("Year-week:O", bin = False, title = "Days of week running"),
        alt.Y(aggregate = "count", type = "quantitative", title = "number of runs")
    )
    #.mark_text
    .properties(
        title = "Numbers of trainings per week",
        width = 1200,
        height = 500
    )
)

chart + labels
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ![](./images/altair-2.png)

# %% [markdown]
# ### Em busca de correr a primeira meira maratona em dezembro de 2019.
#
# - Estabelecendo metas de correr com abaixo de 02:30min, isto dá um pace de 06:30min/km.
# - O objetivo era não quebrar.
#
# <img src="./images/meia_conceicao.jpeg" alt="Meia da Conceicao 2019" style="width: 800px;"/>

# %%
import seaborn as sns

# %%
#Extraindo a meia maratona do nosso dataset
date_race = '2019-12-08'
date_race2 = '2019-12-09'
mask_race = (runs.index >= date_race) & (runs.index <= date_race2)
run_half = runs.loc[mask_race]
run_half
# Out:
#                           Year-month Year-week  total_distance_km  \
# start
# 2019-12-08 09:03:38+00:00    2019-12  2019-w49          21.380738
#
#                            mean_speed_km       mean_pace  mean_pace_float
# start
# 2019-12-08 09:03:38+00:00       7.726149 0 days 00:07:45             7.75

# %%
# training data

plt.figure(figsize=(30,10))

ax = sns.scatterplot(x='total_distance_km', y='mean_pace_float', data=runs, color = 'black')

# race day data
ax1 = sns.scatterplot(x='total_distance_km', y='mean_pace_float', data=run_half, color = 'red', s=100)

ax.set(xlabel="distance, kms", ylabel = "pace, minute km")
plt.axhline(y=6.5, color = "black", linestyle='--', label="target race pace")

# mark race data
plt.text(21.38,8.1,'Race')
plt.legend()
plt.show()

# %% [markdown]
# ### Houve evolução ?

# %%
fig = plt.figure(figsize=(30,10)) #create overall container
ax1 = fig.add_subplot(111) #add a 1 by 1 plot to the figure
x = np.asarray(runs.index)  #convert data to numpy array
y = np.asarray(runs.mean_speed_km)
ax1.plot_date(x, y) #plot data points in scatter plot on ax1
ax1.set_title('Average Speed over Time')
#ax1.set_ylim([0,5])
#add trend line
x2 = mdates.date2num(x)
z=np.polyfit(x2,y,1)
p=np.poly1d(z)
plt.plot(x,p(x2),'r--')
#format the figure and display
fig.autofmt_xdate(rotation=45)
fig.tight_layout()
fig.show()

# %% [markdown]
# ## Anos 2020-2021: Pandemia Covid-19 e criando sustância
#
# <div style="float: left; width: 49%;">
#
# - O objetivo foi melhorar meus tempos nos 21kms.
#
# - Para correr uma maratona de 42kms , é recomendado ter rodado 3-4x meias maratonas para adaptar o corpo e ganhar experiência
#
# - Continuam treinos 1 a 2 x semana.
#
# - Treinos com tiros, longos e variação de ritmo.
#
# </div><div style="float: right; width: 30%;">
#
# <img src="./images/marcel-SP.JPG" alt="Corrida dos circuito do Banco do Brasil 2019
# " style="width: 600px;"/>
#
# Meia Maratona Internacional de São Paulo 2020
#
# </div>

# %%
session = rpd.read_dir_aggregate('./marcel_runs/2020-2021/')
#In this session we compute the distance and the distance per position across all workouts
session = session.session.distance()
#compute the speed for each activity
session = session.session.speed(from_distances=True)
#compute the pace for each activity
session = session.session.pace()
#compute the inactivity periods for each activity
session = session.session.only_moving()
summary_2020_2021 = session.session.summarize()
summary_2020_2021
# Out:
#                               moving_time  mean_speed  max_speed  \
# start
# 2020-01-05 10:23:29+00:00 0 days 00:26:57    1.905871  71.904204
# 2020-01-08 23:34:33+00:00 0 days 00:56:06    2.157448  31.619905
# 2020-01-14 09:11:25+00:00 0 days 01:40:34    2.335246        inf
# 2020-01-19 20:32:05+00:00 0 days 00:54:05    2.144390        inf
# 2020-01-22 22:55:28+00:00 0 days 00:37:19    2.612173        inf
# ...                                   ...         ...        ...
# 2021-12-22 08:33:52+00:00 0 days 00:29:28    2.534843  11.690291
# 2021-12-24 19:51:47+00:00 0 days 00:30:10    2.796910   6.384026
# 2021-12-26 08:28:50+00:00 0 days 03:06:08    2.037052  27.390249
# 2021-12-29 10:41:14+00:00 0 days 00:24:25    2.538219   7.405109
# 2021-12-31 09:43:24+00:00 0 days 00:36:59    2.461658   5.518380
#
#                                 mean_pace        max_pace  mean_moving_speed  \
# start
# 2020-01-05 10:23:29+00:00 0 days 00:08:44 0 days 00:00:13           2.838970
# ...

# %%
summary_2020_2021['days_diff'] = summary_2020_2021.index.to_series().diff().dt.days
summary_2020_2021['total_distance_km'] = summary_2020_2021['total_distance'] / 1000  #conver meters to kms
summary_2020_2021['mean_speed_km'] = summary_2020_2021['mean_speed'] * 3.6 #convert to km/h
summary_2020_2021 = summary_2020_2021.assign(Year=summary_2020_2021.index.year, Month=summary_2020_2021.index.month, Week=summary_2020_2021.index.week, Weekday=summary_2020_2021.index.weekday)
summary_2020_2021['Year-month'] = pd.to_datetime(summary_2020_2021[['Year','Month']].assign(day=1)).dt.to_period('M')
summary_2020_2021['Year-week'] =  summary_2020_2021.index.strftime('%Y-w%U')
def convert_to_minutes(time_delta_obj):
    return time_delta_obj/datetime.timedelta(minutes=1)

summary_2020_2021['mean_pace_float'] = summary_2020_2021['mean_pace'].apply(convert_to_minutes)
summary_2020_2021
# Out:
#                               moving_time  mean_speed  max_speed  \
# start
# 2020-01-05 10:23:29+00:00 0 days 00:26:57    1.905871  71.904204
# 2020-01-08 23:34:33+00:00 0 days 00:56:06    2.157448  31.619905
# 2020-01-14 09:11:25+00:00 0 days 01:40:34    2.335246        inf
# 2020-01-19 20:32:05+00:00 0 days 00:54:05    2.144390        inf
# 2020-01-22 22:55:28+00:00 0 days 00:37:19    2.612173        inf
# ...                                   ...         ...        ...
# 2021-12-22 08:33:52+00:00 0 days 00:29:28    2.534843  11.690291
# 2021-12-24 19:51:47+00:00 0 days 00:30:10    2.796910   6.384026
# 2021-12-26 08:28:50+00:00 0 days 03:06:08    2.037052  27.390249
# 2021-12-29 10:41:14+00:00 0 days 00:24:25    2.538219   7.405109
# 2021-12-31 09:43:24+00:00 0 days 00:36:59    2.461658   5.518380
#
#                                 mean_pace        max_pace  mean_moving_speed  \
# start
# 2020-01-05 10:23:29+00:00 0 days 00:08:44 0 days 00:00:13           2.838970
# ...

# %%
runs_2020_2021 = summary_2020_2021[['Year', 'Year-month', 'Year-week', 'total_distance_km', 'mean_speed_km', 'mean_pace', 'mean_pace_float']].copy()
runs_2020_2021['Year-month'] = runs_2020_2021['Year-month'].astype(str)
runs_2020_2021['Year-week'] =   runs_2020_2021['Year-week'].astype(str)

#juntando os anos de 2019 a 2021.
summary_2019_2020_2021 = pd.concat([runs, runs_2020_2021])
summary_2019_2020_2021
# Out:
#                            Year Year-month Year-week  total_distance_km  \
# start
# 2019-01-06 10:27:21+00:00  2019    2019-01  2019-w01           5.822360
# 2019-01-20 11:30:58+00:00  2019    2019-01  2019-w03           5.275038
# 2019-01-27 08:57:38+00:00  2019    2019-01  2019-w04          10.147025
# 2019-02-03 11:58:15+00:00  2019    2019-02  2019-w05           4.537200
# 2019-02-10 09:40:58+00:00  2019    2019-02  2019-w06           5.320180
# ...                         ...        ...       ...                ...
# 2021-12-22 08:33:52+00:00  2021    2021-12  2021-w51           5.143197
# 2021-12-24 19:51:47+00:00  2021    2021-12  2021-w51           5.129534
# 2021-12-26 08:28:50+00:00  2021    2021-12  2021-w52          26.803528
# 2021-12-29 10:41:14+00:00  2021    2021-12  2021-w52           4.071303
# 2021-12-31 09:43:24+00:00  2021    2021-12  2021-w52           6.104911
#
#                            mean_speed_km       mean_pace  mean_pace_float
# start
# ...

# %%
import matplotlib.pyplot as plt
fig, axr = plt.subplots(1,3, figsize=(60,20 ))

ticks = summary_2019_2020_2021.groupby(summary_2019_2020_2021['Year']).agg({'total_distance_km': 'sum'}).index.astype('str').to_list()


axr[0].bar(summary_2019_2020_2021.groupby(summary_2019_2020_2021['Year']).agg({'total_distance_km': 'sum'}).index.astype('str'), 
            summary_2019_2020_2021.groupby(summary_2019_2020_2021['Year']).agg({'total_distance_km': 'sum'}).values.flatten(),
        yerr=summary_2019_2020_2021.groupby(summary_2019_2020_2021['Year']).agg({'total_distance_km': 'std'}).values.flatten(),
        tick_label=ticks, label='Number of kilometers')
axr[0].set_title('Total number of kilometers')
axr[0].set_ylabel('Km')
summary_2019_2020_2021.boxplot(['mean_speed_km'], by='Year', ax=axr[1])
axr[1].set_xticklabels(ticks)
axr[1].set_ylabel('Km/h')
summary_2019_2020_2021.groupby('Year')['mean_speed_km'].count().plot.bar(ax=axr[2], color='C1')
axr[2].set_xticklabels(ticks)
axr[2].set_title('Number of trainings')
plt.show()

# %%
plt.subplots(figsize=(30, 10))

plt.plot(summary_2019_2020_2021.index, summary_2019_2020_2021.mean_pace_float, color='silver', label = 'average pace')


#add trend line
x = np.asarray(summary_2019_2020_2021.index)  #convert data to numpy array
x2 = mdates.date2num(x)
y = np.asarray(summary_2019_2020_2021.mean_pace_float)
z=np.polyfit(x2,y,1)
p=np.poly1d(z)
plt.plot(x,p(x2),'r--')
#format the figure and display
fig.autofmt_xdate(rotation=45)
fig.tight_layout()
fig.show()
plt.title("Pace Evolution")
plt.xlabel("Runnings")
plt.ylabel("Pace")
plt.legend()

# %% [markdown]
# ### Tentando localizar correlação entre as colunas numéricas

# %%
sns.pairplot(summary_2019_2020_2021, height=3, aspect=3)

# %%
corr = summary_2019_2020_2021.corr()
plt.figure(figsize = (30,15))
sns.heatmap(corr, annot=True, fmt=".2f");

# %% [markdown]
# ### Vamos ver meu desempenho nas minhas distâncias de 5km, 10km, 21km

# %%
summary_5km = summary_2019_2020_2021[summary_2019_2020_2021['total_distance_km'].between(5,5.9)]
summary_10km = summary_2019_2020_2021[summary_2019_2020_2021['total_distance_km'].between(10,10.9)]
summary_21km = summary_2019_2020_2021[summary_2019_2020_2021['total_distance_km'].between(21,21.9)]


summary_21km
# Out:
#                            Year Year-month Year-week  total_distance_km  \
# start
# 2019-12-08 09:03:38+00:00  2019    2019-12  2019-w49          21.380738
# 2021-09-18 18:59:43+00:00  2021    2021-09  2021-w37          21.083172
# 2021-12-12 09:04:45+00:00  2021    2021-12  2021-w50          21.243015
#
#                            mean_speed_km       mean_pace  mean_pace_float
# start
# 2019-12-08 09:03:38+00:00       7.726149 0 days 00:07:45         7.750000
# 2021-09-18 18:59:43+00:00       9.504917 0 days 00:06:18         6.300000
# 2021-12-12 09:04:45+00:00       9.116087 0 days 00:06:34         6.566667

# %%
fig, axs = plt.subplots(1,3, figsize=(40, 10))
fig.suptitle('Average Moving Pace over time (5km, 10km, 21km)')

axs[0].plot(summary_5km.index, summary_5km.mean_pace_float, marker='*')
axs[0].set_title('5km')
axs[1].plot(summary_10km.index, summary_10km.mean_pace_float, marker='*')
axs[1].set_title('10km')


axs[2].plot(summary_21km.index, summary_21km.mean_pace_float, marker='*')
axs[2].set_title('21km')

plt.xlabel('Date')
plt.show()

# %% [markdown]
# ### Resumo
#
#
# <div style="float: left; width: 49%;">
#
# - Não houve uma melhora consistente em meus resultados, muitas variações durante o ano. Especialmente na lacuna de 2020.1 onde tive COVID.
#
# - Houve uma melhora na meia maratona, de fato, mas ainda bem acima do desejado com pace de 06:30min/km no máximo.
#
# - Estava já com 3-4 meia maratonas na bagagem, em busca do próximo desafio.
#
# - Troca de relógio (Apple Watch foi legal, mas realmente os Garmins surpreendem!)
#
# </div><div style="float: right; width: 30%;">
#
# <img src="./images/half-marathon.png" alt="Meme" style="width: 500px;"/>
#
# </div>

# %% [markdown]
# ## Ano 2022: Ano que reaprendi a correr
#
# <div style="float: left; width: 49%;">
#
# - Objetivo: Me preparar para minha primeira maratona.
#
# - Entrei para uma asssessoria de corrida, a Recife Runners. Grupo especializado em treinamentos de corrida de rua.
#
# - Volume e carga de treinos aumentaram de 2 para 4x semana.
#
# - Busca de apoio multi-profissional: Nutrição, cardiológico e Fisioterapia.
#
# </div><div style="float: right; width: 30%;">
#
# <img src="./images/ladeira-conceicao.png" alt="Corrida dos circuito do Banco do Brasil 2019
# " style="width: 400px;"/>
#
# Treino de ladeira em 2022
#
# </div>

# %% [markdown]
# ### Antes de aprofundarmos sobre 2022, preciso apresentar alguns conceitos novos:  Zonas por treino de frequência cardíaca
#
#
# - Treinamento por zona de intensidade de esforço é um dos modelos para personalizar o treinamento de corrida. [5, 6]
#
# - Ficou muito popular e difundido pelos treinadores de corrida de alto desempenho.
#
# <img src="./images/zonas-treinamento.jpeg" alt="Corrida dos circuito do Banco do Brasil 2019
# " style="width: 1000px;"/>

# %% [markdown]
# ![](./images/Training-Zone-Calculator-1.png)

# %% [markdown]
# ### Exemplo prático
#
# - Quando eu recebo uma planilha abaixo, como fica minha zona de frequência cardiáca na prática ?
#
#
# <center>
# <img src="./images/treinus.jpeg" alt="Corrida dos circuito do Banco do Brasil 2019
# " style="width: 600px;"/>
# </center>

# %%
### Exemplo prático
import runpandas
activity = runpandas.read_file('./marcel_runs/hr/activity_9374502822.gpx')
print('Start', activity.index[0],'End:', activity.index[-1])
print(activity.iloc[0]['lat'], activity.iloc[-1]['lat'])
# Out:
# Start 0 days 00:00:00 End: 0 days 01:02:55
# -8.036022260785103 -8.036168944090605

# %%
group_hr = activity['hr'].isnull().sum()
print("There are nan records: %d" % group_hr)
# Out:
# There are nan records: 0

# %%
#compute the distance using haversine formula between two consecutive latitude, longitudes observations.
activity['distpos']  = activity.compute.distance()
activity['distpos'].head()
# Out:
# time
# 0 days 00:00:00         NaN
# 0 days 00:00:01    1.196757
# 0 days 00:00:06    8.506102
# 0 days 00:00:09    4.315176
# 0 days 00:00:13    9.552396
# Name: distpos, dtype: float64

# %%
#compute the distance using haversine formula between two consecutive latitude, longitudes observations.
activity['speed']  = activity.compute.speed(from_distances=True)
activity['speed'].head()
# Out:
# time
# 0 days 00:00:00         NaN
# 0 days 00:00:01    1.196757
# 0 days 00:00:06    1.701220
# 0 days 00:00:09    1.438392
# 0 days 00:00:13    2.388099
# Name: speed, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.patches as mpatches
from matplotlib import pyplot as plt
plt.style.use('seaborn-poster')


ZONE_COLORS_0 = {
    1: '#ffffcc',
    2: '#a1dab4',
    3: '#41b6c4',
    4: '#2c7fb8',
    5: '#253494'
}

def format_time_delta(time_delta):
    """Create string after formatting time deltas."""
    timel = []
    for i in time_delta:
        hours, res = divmod(i, 3600)
        minutes, seconds = divmod(res, 60)
        timel.append('{:02d}:{:02d}:{:02d}'.format(int(hours), int(minutes),
                                                   int(seconds)))
    return timel

def _make_time_labels(delta_seconds, nlab=5):
    """Make n time formatted labels for data i seconds"""
    label_pos = np.linspace(min(delta_seconds), max(delta_seconds),
                            nlab, dtype=np.int_)
    label_lab = format_time_delta(label_pos)
    return label_pos, label_lab

def heart_rate_zone_limits(maxpulse=187):
    """Return the limits for the heart rate zones."""
    lims = [(0.5, 0.6), (0.6, 0.7), (0.7, 0.8), (0.8, 0.9), (0.9, 1.0)]
    return [(maxpulse * i[0], maxpulse * i[1]) for i in lims]

def plot_hr(data, maxpulse=184):
    """Plot the heart rate per time with training zones."""
    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    ax1.set_facecolor('0.90')
    xdata = data.index.total_seconds().tolist()
    ydata = data['hr'].tolist()
    handles = []
    legends = []
    zones = heart_rate_zone_limits(maxpulse=maxpulse)
    for i, zone in enumerate(zones):
        patch = mpatches.Patch(color=ZONE_COLORS_0[i+1])
        legend = 'Zone = {}'.format(i + 1)
        handles.append(patch)
        legends.append(legend)
        ax1.axhspan(zone[0], zone[1], color=ZONE_COLORS_0[i+1])
    ax1.plot(xdata, ydata, color='#262626', lw=3)
    ax1.legend(handles, legends)
    ax1.set_ylim(min(ydata) - 2, max(ydata) + 2)
    label_pos, label_lab = _make_time_labels(xdata, 5)
    ax1.set_xticks(label_pos)
    ax1.set_xticklabels(label_lab, rotation=25)
    ax1.set_xlabel('Time')
    ax1.set_ylabel('Heart rate / bpm')
    fig.tight_layout()
    return fig

fig = plot_hr(activity, maxpulse=182)

# %%
from matplotlib.cm import get_cmap

plt.style.use('seaborn-talk')


def find_regions(yval):
    """Find borders for regions with equal values.
    Parameters
    ----------
    yval : array_like
        The values we are to locate regions for.
    Returns
    -------
    new_regions : list of lists of numbers
        The regions where yval is constant. These are on the form
        ``[start_index, end_index, constant_y]`` with the
        interpretation that ``yval=constant-y`` for the index
        range ``[start_index, end_index]``
    """
    regions = []
    region_y = None
    i = None
    for i, ypos in enumerate(yval):
        if region_y is None:
            region_y = ypos
        if ypos != region_y:
            regions.append([i, region_y])
            region_y = ypos
    # for adding the last region
    if i is not None:
        regions.append([i, region_y])
    new_regions = []
    for i, region in enumerate(regions):
        if i == 0:
            reg = [0, region[0], region[1]]
        else:
            reg = [regions[i-1][0], region[0], region[1]]
        new_regions.append(reg)
    return new_regions

def calculate_hr_zones(data, max_heart_rate=182):
    limits = heart_rate_zone_limits(max_heart_rate)
    bins = [i[0] for i in limits]
    hr_zone = np.digitize(data['hr'], bins, right=False)
    hr_zone_limis = find_regions(hr_zone)
    return hr_zone_limis


def get_limits_text(max_heart_rate=184):
    limits = heart_rate_zone_limits(max_heart_rate)
    txt = {
        0: f'$<${int(limits[0][0])} bpm',
        1: f'{int(limits[0][0])}‒{int(limits[0][1])} bpm',
        2: f'{int(limits[1][0])}‒{int(limits[1][1])} bpm',
        3: f'{int(limits[2][0])}‒{int(limits[2][1])} bpm',
        4: f'{int(limits[3][0])}‒{int(limits[3][1])} bpm',
        5: f'$>${int(limits[3][1])} bpm',
    }
    return txt

def plot_hr_distribution(data):
    fig = plt.figure()
    ax1 = fig.add_subplot(111)

    time = data.index.total_seconds().tolist()
    time_in_zones = {}
    for start, stop, value in calculate_hr_zones(activity):
        seconds = (time[stop] - time[start])
        if value not in time_in_zones:
            time_in_zones[value] = 0
        time_in_zones[value] += seconds
    sum_time = sum([val for _, val in time_in_zones.items()])
    # Check consistency:
    print('Times are equal?', sum_time == (time[-1] - time[0]))

    zone_txt = get_limits_text()

    zones = sorted(list(time_in_zones.keys()))
    percent = {
        key: 100 * val / sum_time for key, val in            
        time_in_zones.items()
    }
    labels = [
        f'Zone {i} ({zone_txt[i]})\n({percent[i]:.1f}%)' for i in zones
    ]
    values = [time_in_zones[i] for i in zones]
    times = format_time_delta(values)
    cmap = get_cmap(name='Reds')
    colors = cmap(np.linspace(0, 1, len(zones) + 1))
    colors = colors[1:]  # Skip the first color
    rects = ax1.barh(zones, values, align='center', tick_label=labels)
    for i, recti in enumerate(rects):
        recti.set_facecolor(colors[i])
        width = int(recti.get_width())
        yloc = recti.get_y() + recti.get_height() / 2
        ax1.annotate(
                times[i],
                xy=(width, yloc),
                xytext=(3, 0),
                textcoords="offset points",
                ha='left', va='center',
                fontsize='x-large'
        )
    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)
    ax1.spines['bottom'].set_visible(False)
    ax1.tick_params(bottom=False)
    ax1.tick_params(labelbottom=False)
    fig.tight_layout()
    return fig

fig = plot_hr_distribution(activity)
# Out:
# Times are equal? True

# %% [markdown]
# ### Vamos a alguns números agora de 2022  (corridas até agosto 2022)

# %%
session = rpd.read_dir_aggregate('./marcel_runs/2022/')
#In this session we compute the distance and the distance per position across all workouts
session = session.session.distance()
#compute the speed for each activity
session = session.session.speed(from_distances=True)
#compute the pace for each activity
session = session.session.pace()
#compute the inactivity periods for each activity
session = session.session.only_moving()
summary_2022 = session.session.summarize()
summary_2022
# Out:
#                               moving_time  mean_speed   max_speed  \
# start
# 2022-01-04 09:16:16+00:00 0 days 00:50:52    2.470235    4.225963
# 2022-01-08 08:25:25+00:00 0 days 00:56:31    2.610522    6.261465
# 2022-01-10 08:22:59+00:00 0 days 00:59:18    2.444685   11.631367
# 2022-01-12 08:27:08+00:00 0 days 00:35:14    2.286067    6.235679
# 2022-01-16 09:16:07+00:00 0 days 01:44:09    2.303163    8.172271
# ...                                   ...         ...         ...
# 2022-08-13 07:59:43+00:00 0 days 02:42:56    2.666236    4.303183
# 2022-08-15 08:20:02+00:00 0 days 00:46:14    2.826207  310.960633
# 2022-08-17 08:19:07+00:00 0 days 00:47:18    2.575003    5.011086
# 2022-08-19 08:44:03+00:00 0 days 00:49:03    2.586370    7.453324
# 2022-08-20 07:25:14+00:00 0 days 03:14:39    2.566520    5.854653
#
#                                 mean_pace        max_pace  mean_moving_speed  \
# start
# 2022-01-04 09:16:16+00:00 0 days 00:06:44 0 days 00:03:56           2.641824
# ...

# %%
summary_2022['days_diff'] = summary_2022.index.to_series().diff().dt.days
summary_2022['total_distance_km'] = summary_2022['total_distance'] / 1000  #conver meters to kms
summary_2022['mean_speed_km'] = summary_2022['mean_speed'] * 3.6 #convert to km/h
summary_2022['mean_moving_speed'] = summary_2022['mean_moving_speed'] * 3.6 #convert to km/h
summary_2022 = summary_2022.assign(Year=summary_2022.index.year, Month=summary_2022.index.month, Week=summary_2022.index.week, Weekday=summary_2022.index.weekday)
summary_2022['Year-month'] = pd.to_datetime(summary_2022[['Year','Month']].assign(day=1)).dt.to_period('M')
summary_2022['Year-week'] =  summary_2022.index.strftime('%Y-w%U')
def convert_to_minutes(time_delta_obj):
    return time_delta_obj/datetime.timedelta(minutes=1)

summary_2022['mean_moving_pace_float'] = summary_2022['mean_moving_pace'].apply(convert_to_minutes)
summary_2022['mean_pace_float'] = summary_2022['mean_pace'].apply(convert_to_minutes)

# %%
summary['days_diff'] = summary.index.to_series().diff().dt.days
summary['total_distance'] = summary['total_distance'] / 1000  #conver meters to kms
summary['mean_speed'] = summary['mean_speed'] * 3.6 #convert to km/h

# %%
import matplotlib.pyplot as plt
fig, axr = plt.subplots(1,3 ,figsize=(60,20 ))

ticks = summary_2022.groupby(summary_2022['Year-month']).agg({'total_distance_km': 'sum'}).index.astype('str').to_list()


axr[0].bar(summary_2022.groupby(summary_2022['Year-month']).agg({'total_distance_km': 'sum'}).index.astype('str'), 
            summary_2022.groupby(summary_2022['Year-month']).agg({'total_distance_km': 'sum'}).values.flatten(),
        yerr=summary_2022.groupby(summary_2022['Year-month']).agg({'total_distance_km': 'std'}).values.flatten(),
        tick_label=ticks, label='Number of kilometers')
axr[0].set_title('Total number of kilometers')
axr[0].set_ylabel('Km')
summary_2022.boxplot(['mean_moving_speed'], by='Year-month', ax=axr[1])
axr[1].set_xticklabels(ticks)
axr[1].set_ylabel('Km/h')
summary_2022.groupby('Year-month')['mean_moving_speed'].count().plot.bar(ax=axr[2], color='C1')
axr[2].set_xticklabels(ticks)
axr[2].set_title('Number of trainings')
plt.show()

# %%
summary_2022.total_distance_km.cumsum().plot(title='Total workout distance (km)',lw=2)
# Out:
# <AxesSubplot:title={'center':'Total workout distance (km)'}, xlabel='start'>

# %% [markdown]
# ### Meia Maratona do Rio De Janeiro (Junho de 2022) e Ciclo de preparo para maratona.
#
# <div style="float: left; width: 49%;">
#
# - Primeira prova teste para avaliar meu desempenho.
#
# - Início do ciclo de preparo para maratona.
#
# - Maratona de 42kms envolve muitos treinos , longos e especialmente a mente. Ciclo de pelo menos 4 meses de preparo.
#
# - Se prepare para fazer várias meias maratonas para cima por vários fins de semana seguidos.
#
# </div><div style="float: right; width: 30%;">
#
# <img src="./images/marcel-rio.png" alt="Meia Maratona do Rio 2022
# " style="width: 500px;"/>
#
# Meia Maratona do Rio 2022
# </div>

# %%
fig,ax = plt.subplots(figsize=(16,10))
ax.set_title('Running Distance (km)')
ax.plot(summary_2022.index,summary_2022.total_distance_km,'bo--')
arrowprops=dict(arrowstyle='<-', color='red')
ax.annotate(text='Meia do Rio - Inicio Ciclo',xy=((datetime.datetime.strptime('2022-06-18','%Y-%m-%d')),21.1),\
           xytext=((datetime.datetime.strptime('2022-06-20','%Y-%m-%d')),27.0),\
           arrowprops=arrowprops);

# %% [markdown]
# ### Você realmente se trabalhar bem em todos os aspectos (corpo, mente e dedicação você pode evoluir muito em seus treinos de menor distância)

# %%
pace1 = []
pace2 = []
for date,pace in zip(summary_2022.index,summary_2022['mean_moving_pace_float']):
    if date.month<7 and date.month >= 4:
        pace1.append(pace)
        pace2.append(np.nan)
    else:
        pace1.append(np.nan)
        pace2.append(pace)

df2 = pd.DataFrame({'Antes do ciclo da meia maratona (2 meses' : pd.Series(pace1,index=summary_2022.index), 
                    'Após ciclo da meia maratona (2 meses)' : pd.Series(pace2,index=summary_2022.index)})
df2.plot(kind='hist',stacked=True,fontsize=15)
plt.ylabel('# of runs');

# %%
fig = plt.figure(figsize=(16,10)) #create overall container
ax1 = fig.add_subplot(111) #add a 1 by 1 plot to the figure
x = np.asarray(summary_2022.index)  #convert data to numpy array
y = np.asarray(summary_2022.mean_moving_speed)
ax1.plot_date(x, y) #plot data points in scatter plot on ax1
ax1.set_title('Average Speed over Time')
#ax1.set_ylim([0,5])
#add trend line
x2 = mdates.date2num(x)
z=np.polyfit(x2,y,1)
p=np.poly1d(z)
plt.plot(x,p(x2),'r--')
#format the figure and display
fig.autofmt_xdate(rotation=45)
fig.tight_layout()
fig.show()

# %%
### Minha evolução em 2022

summary_all = pd.concat([summary_2019_2020_2021, summary_2022])

#Fill NA GAPs if any missing]
summary_all.loc[summary_all['mean_moving_pace_float'].isnull(),'mean_moving_pace_float'] = summary_all['mean_pace_float']

summary_10km = summary_all[summary_all['total_distance_km'].between(10,10.9)]
summary_21km = summary_all[summary_all['total_distance_km'].between(21,21.9)]

# %%
fig, axs = plt.subplots(1,2, figsize=(40, 10))
fig.suptitle('Average Moving Pace over time (10km, 21km)')

axs[0].plot(summary_10km.index, summary_10km.mean_moving_pace_float, marker='*')
axs[0].set_title('10km')


axs[1].plot(summary_21km.index, summary_21km.mean_moving_pace_float, marker='*')
axs[1].set_title('21km')

plt.xlabel('Date')
plt.show()

# %%
runs_all = summary_all[['Year', 'total_distance_km', 'mean_heart_rate', 'mean_moving_pace_float']].copy()

chart = (
    alt.Chart(
        runs_all
    )
    .mark_point(
        filled = True,
        clip = True
    )
    .encode(
        alt.X(
            "total_distance_km:Q", 
            title = "Kilometer", 
            scale = alt.Scale(),
            
        ),
        alt.Y(
            "mean_moving_pace_float:Q", 
            title = "Average Pace", 
            scale = alt.Scale(domain = (5, 12)),
            axis = alt.Axis(labels = False)
        ),
        #color = alt.Color("runYear:N", legend = alt.Legend(title = "year")),
        color = alt.Color("Year:N", legend = None),
        column = "Year:O"
    )
    #.mark_text
    .properties(
        title = "Relationship between pace and Distance",
        width = 700,
        height = 600
    )
    .transform_calculate(
    # Generate Gaussian jitter with a Box-Muller transform
        jitter='sqrt(-2*log(random()))*cos(2*PI*random())'
    )
)

chart
# Out:
# alt.Chart(...)

# %%
chart = (
    alt.Chart(runs_all)
    .mark_circle(
        #size = 14
    )
    .encode(
        # X-axis jitter Vertical
        x = alt.X(
            'jitter:Q',
            #title = "year",
            title = None,
            axis = alt.Axis(ticks = True, grid = False, labels = False),
            scale = alt.Scale(),
        ),
        y = alt.Y(
            'total_distance_km:Q',
            scale = alt.Scale(),
            title = "run distances in KM"
        ),
        color = alt.Color('Year:N', legend = None),
        column = alt.Column(
            'Year:N',
            title = "year"
            ),
    )
    .transform_calculate(
        # Generate Gaussian jitter with a Box-Muller transform
        jitter = "sqrt(-1*log(random()))*cos(2*PI*random())"
    )
    .properties(
        title = "2019-2022",
        width = 700,
        height = 500
    )
)
    
chart
# Out:
# alt.Chart(...)

# %%
summary_19_20_21_22 = pd.concat([summary, summary_2020_2021, summary_2022])

runs_all = summary_19_20_21_22[['Year', 'total_distance_km', 'mean_heart_rate']].copy()


chart = (
    alt.Chart(runs_all)
    .mark_circle(clip = True)
    .encode(
        # X-axis jitter Vertical
        x = alt.X(
            'jitter:Q',
            #title = "year",
            title = None,
            axis = alt.Axis(ticks = True, grid = False, labels = False),
            scale = alt.Scale(zero = True),
        ),
        y = alt.Y(
            'mean_heart_rate:Q',
            scale = alt.Scale(domain = (100, 190)),
            title = "Average HR (beats per minute)"
        ),
        color = alt.Color('Year:N', legend = None),
        column = alt.Column(
            'Year:N',
            title = "YEAR"
            ),
    )
    .transform_calculate(
        # Generate Gaussian jitter with a Box-Muller transform
        jitter = "sqrt(-1*log(random()))*cos(2*PI*random())"
    )
    .properties(
        title = "2019-2022",
        width = 500,
        height = 500
    )
    
)

chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Agora que temos um panorama completo, de como corro até hoje, vamos olhar para a Maratona!
#
# ### Lochness Marathon
#
# - Situado no norte do Reino Unido.
#
# - Famoso pela fábula do lago Ness e o monstro do lago.
#
#
# ![](./images/lochness.jpeg)

# %% [markdown]
# ### Informações de  Percurso
#
# - Percurso no mapa
# - Altimetria

# %%
import gpxpy
import pandas as pd

# Load gpx.
gpx_path = './marcel_runs/course/lochness.gpx'
with open(gpx_path) as f:
    gpx = gpxpy.parse(f)

# Convert to a dataframe one point at a time.
points = []
for segment in gpx.tracks[0].segments:
    for p in segment.points:
        points.append({
            'time': p.time,
            'latitude': p.latitude,
            'longitude': p.longitude,
            'elevation': p.elevation,
        })
course = pd.DataFrame.from_records(points)
course
# Out:
#      time   latitude  longitude  elevation
# 0    None  57.186570   -4.53028     226.22
# 1    None  57.187208   -4.52943     223.19
# 2    None  57.187845   -4.52858     221.65
# 3    None  57.188483   -4.52773     220.60
# 4    None  57.189120   -4.52688     220.64
# ..    ...        ...        ...        ...
# 704  None  57.465230   -4.24249      18.34
# 705  None  57.465240   -4.24226      17.85
# 706  None  57.465210   -4.24216      17.85
# 707  None  57.465250   -4.24193      17.57
# 708  None  57.465320   -4.24168      17.16
#
# [709 rows x 4 columns]

# %%
plt.figure(figsize=(14, 8))
plt.scatter(course['longitude'], course['latitude'], color='#101010')
plt.title('Route latitude and longitude points', size=20);

# %%
import folium

route_map = folium.Map(
    location=[57.34717000082745, -4.372500005460566],
    zoom_start=10,
    tiles='OpenStreetMap',
    width=850,
    height=600
)

coordinates = [tuple(x) for x in course[['latitude', 'longitude']].to_numpy()]
folium.PolyLine(coordinates, weight=6).add_to(route_map)

display(route_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
course['elevation_diff'] = course['elevation'].diff()
course.head()
# Out:
#    time   latitude  longitude  elevation  elevation_diff
# 0  None  57.186570   -4.53028     226.22             NaN
# 1  None  57.187208   -4.52943     223.19           -3.03
# 2  None  57.187845   -4.52858     221.65           -1.54
# 3  None  57.188483   -4.52773     220.60           -1.05
# 4  None  57.189120   -4.52688     220.64            0.04

# %%
import numpy as np
import haversine as hs

def haversine_distance(lat1, lon1, lat2, lon2):
    distance = hs.haversine(
        point1=(lat1, lon1),
        point2=(lat2, lon2),
        unit=hs.Unit.METERS
    )
    return np.round(distance, 2)

distances = [np.nan]

for i in range(len(course)):
    if i == 0:
        continue
    else:
        distances.append(haversine_distance(
            lat1=course.iloc[i - 1]['latitude'],
            lon1=course.iloc[i - 1]['longitude'],
            lat2=course.iloc[i]['latitude'],
            lon2=course.iloc[i]['longitude']
        ))

course['distance'] = distances
course.head()
# Out:
#    time   latitude  longitude  elevation  elevation_diff  distance
# 0  None  57.186570   -4.53028     226.22             NaN       NaN
# 1  None  57.187208   -4.52943     223.19           -3.03     87.45
# 2  None  57.187845   -4.52858     221.65           -1.54     87.45
# 3  None  57.188483   -4.52773     220.60           -1.05     87.45
# 4  None  57.189120   -4.52688     220.64            0.04     87.45

# %%
print('Elevation Profile', course[course['elevation_diff'] >= 0]['elevation_diff'].sum(), 'meters')
print('Distance', course['distance'].sum() / 1000, 'meters')
# Out:
# Elevation Profile 297.45000000000016 meters
# Distance 42.49121000000001 meters

# %%
course['cum_elevation'] = course['elevation_diff'].cumsum()
course['cum_distance'] = course['distance'].cumsum()
course.head()
# Out:
#    time   latitude  longitude  elevation  elevation_diff  distance  \
# 0  None  57.186570   -4.53028     226.22             NaN       NaN
# 1  None  57.187208   -4.52943     223.19           -3.03     87.45
# 2  None  57.187845   -4.52858     221.65           -1.54     87.45
# 3  None  57.188483   -4.52773     220.60           -1.05     87.45
# 4  None  57.189120   -4.52688     220.64            0.04     87.45
#
#    cum_elevation  cum_distance
# 0            NaN           NaN
# 1          -3.03         87.45
# 2          -4.57        174.90
# 3          -5.62        262.35
# 4          -5.58        349.80

# %%
course = course.fillna(0)
course.head()
# Out:
#    time   latitude  longitude  elevation  elevation_diff  distance  \
# 0     0  57.186570   -4.53028     226.22            0.00      0.00
# 1     0  57.187208   -4.52943     223.19           -3.03     87.45
# 2     0  57.187845   -4.52858     221.65           -1.54     87.45
# 3     0  57.188483   -4.52773     220.60           -1.05     87.45
# 4     0  57.189120   -4.52688     220.64            0.04     87.45
#
#    cum_elevation  cum_distance
# 0           0.00          0.00
# 1          -3.03         87.45
# 2          -4.57        174.90
# 3          -5.62        262.35
# 4          -5.58        349.80

# %%
plt.plot(course['cum_distance'], course['cum_elevation'], color='#101010', lw=3)
plt.title('Route elevation profile', size=20)
plt.xlabel('Distance in meters', size=14)
plt.ylabel('Elevation in meters', size=14);

# %% [markdown]
# ### Possível saber a proporção em distância do percurso que vou enfrentar elevações ?
#
# - Vamos aprender sobre o gradiente.
# - Quantos metros de subida você ganha após 100 metros de distância?
#
# ![](./images/gradient.jpeg)

# %%
gradients = [np.nan]

for ind, row in course.iterrows(): 
    if ind == 0:
        continue
    grade = (row['elevation_diff'] / row['distance']) * 100
    gradients.append(np.round(grade, 1))
gradients[:10]
# Out:
# [nan, -3.5, -1.8, -1.2, 0.0, 0.1, -0.2, -1.9, -1.0, -3.6]

# %%
plt.title('Terrain gradient on the route', size=20)
plt.xlabel('Data point', size=14)
plt.ylabel('Gradient (%)', size=14)
plt.plot(np.arange(len(gradients)), gradients, lw=2, color='#101010');

# %%
course['gradient'] = gradients
course['gradient'].describe()
# Out:
# count    708.000000
# mean      -0.505226
# std        3.387637
# min      -23.600000
# 25%       -1.600000
# 50%       -0.200000
# 75%        0.600000
# max       15.500000
# Name: gradient, dtype: float64

# %%
course['gradient'] = course['gradient'].interpolate().fillna(0)
course.head()
# Out:
#    time   latitude  longitude  elevation  elevation_diff  distance  \
# 0     0  57.186570   -4.53028     226.22            0.00      0.00
# 1     0  57.187208   -4.52943     223.19           -3.03     87.45
# 2     0  57.187845   -4.52858     221.65           -1.54     87.45
# 3     0  57.188483   -4.52773     220.60           -1.05     87.45
# 4     0  57.189120   -4.52688     220.64            0.04     87.45
#
#    cum_elevation  cum_distance  gradient gradient_range
# 0           0.00          0.00       0.0            NaN
# 1          -3.03         87.45      -3.5   [-5.0, -3.0)
# 2          -4.57        174.90      -1.8   [-3.0, -1.0)
# 3          -5.62        262.35      -1.2   [-3.0, -1.0)
# 4          -5.58        349.80       0.0     [0.0, 1.0)

# %%
bins = pd.IntervalIndex.from_tuples([
    (-30, -10),
    (-10, -5), 
    (-5, -3), 
    (-3, -1), 
    (-1, 0),
    (0, 1), 
    (1, 3), 
    (3, 5), 
    (5, 7), 
    (7, 10), 
    (10, 12), 
    (12, 15), 
    (15, 20)
], closed='left')
bins
# Out:
# IntervalIndex([[-30, -10), [-10, -5), [-5, -3), [-3, -1), [-1, 0) ... [5, 7), [7, 10), [10, 12), [12, 15), [15, 20)],
#               closed='left',
#               dtype='interval[int64]')

# %%
course['gradient_range'] = pd.cut(course['gradient'], bins=bins)
course.head()
# Out:
#    time   latitude  longitude  elevation  elevation_diff  distance  \
# 0     0  57.186570   -4.53028     226.22            0.00      0.00
# 1     0  57.187208   -4.52943     223.19           -3.03     87.45
# 2     0  57.187845   -4.52858     221.65           -1.54     87.45
# 3     0  57.188483   -4.52773     220.60           -1.05     87.45
# 4     0  57.189120   -4.52688     220.64            0.04     87.45
#
#    cum_elevation  cum_distance  gradient gradient_range
# 0           0.00          0.00       0.0         [0, 1)
# 1          -3.03         87.45      -3.5       [-5, -3)
# 2          -4.57        174.90      -1.8       [-3, -1)
# 3          -5.62        262.35      -1.2       [-3, -1)
# 4          -5.58        349.80       0.0         [0, 1)

# %%
gradient_details = []

# For each unique gradient range
for gr_range in course['gradient_range'].unique():
    # Keep that subset only
    subset = course[course['gradient_range'] == gr_range]
    
    # Statistics
    total_distance = subset['distance'].sum()
    pct_of_total_ride = (subset['distance'].sum() / course['distance'].sum()) * 100
    elevation_gain = subset[subset['elevation_diff'] > 0]['elevation_diff'].sum()
    elevation_lost = subset[subset['elevation_diff'] < 0]['elevation_diff'].sum()
    
    # Save results
    gradient_details.append({
        'gradient_range': gr_range,
        'total_distance': np.round(total_distance, 2),
        'pct_of_total_ride': np.round(pct_of_total_ride, 2),
        'elevation_gain': np.round(elevation_gain, 2),
        'elevation_lost': np.round(np.abs(elevation_lost), 2)
    })

# %%
gradient_details_df = pd.DataFrame(gradient_details).sort_values(by='gradient_range').reset_index(drop=True)
gradient_details_df
# Out:
#    gradient_range  total_distance  pct_of_total_ride  elevation_gain  \
# 0      [-30, -10)          425.24               1.00            0.00
# 1       [-10, -5)         1841.57               4.33            0.00
# 2        [-5, -3)         3075.62               7.24            0.00
# 3        [-3, -1)         8751.48              20.60            0.00
# 4         [-1, 0)         9536.80              22.44            0.00
# 5          [0, 1)        11249.70              26.48           41.51
# 6          [1, 3)         4585.17              10.79           81.58
# 7          [3, 5)         1504.80               3.54           58.25
# 8          [5, 7)          962.02               2.26           60.33
# 9         [7, 10)          312.23               0.73           26.95
# 10       [10, 12)          120.07               0.28           12.35
# 11       [12, 15)          110.85               0.26           14.06
# 12       [15, 20)           15.66               0.04            2.42
#
# ...

# %%
colors = [
    '#0d46a0', '#2f3e9e', '#2195f2', '#4fc2f7',
    '#a5d6a7', '#66bb6a', '#fff59d', '#ffee58',
    '#ffca28', '#ffa000', '#ff6f00', '#f4511e', '#bf360c'
]
custom_text = [f'''<b>{gr}%</b> - {dst}km''' for gr, dst in zip(
    gradient_details_df['gradient_range'].astype('str'),
    gradient_details_df['total_distance'].apply(lambda x: round(x / 1000, 2))
)]

# %%
import plotly.graph_objects as go

fig = go.Figure(
    data=[go.Bar(
        x=gradient_details_df['gradient_range'].astype(str),
        y=gradient_details_df['total_distance'].apply(lambda x: round(x / 1000, 2)),
        marker_color=colors,
        text=custom_text
    )],
    layout=go.Layout(
        bargap=0,
        title='Gradient profile of a route',
        xaxis_title='Gradient range (%)',
        yaxis_title='Distance covered (km)',
        autosize=False,
        width=1440,
        height=800,
        template='simple_white'
    )
)
fig.show()

# %% [markdown]
# ### Entendendo um pouco sobre dados demográficos da Corrida de Lochness

# %% [markdown]
# ### É possível prever meu tempo na maratona ?
#
# - Podemos fazer um exercício de predição usando técnicas simples de aprendizagem de máquina estatística.
# - Usando meus dados históricos e aplicando ``regressão linear``
#
# ![](./images/linear-regression.png)

# %% [markdown]
# ### Usando meu histórico de 2022, vamos tentar prever meu tempo nos meus primeiros 42kms

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
#convert time ellapse to minutes format
summary_2022['ellapsed_time_minutes'] = summary_2022['ellapsed_time'] / np.timedelta64(1, 'm')


X_train = summary_2022[['total_distance_km']].values
Y_train = summary_2022['ellapsed_time_minutes']
X_test = np.array([42.195]).reshape(1,-1)

# %%
regr = linear_model.LinearRegression()
regr.fit(X_train, Y_train)
Y_pred = regr.predict(X_test)
print('Distance: {} Km, Speed: {} Km/h, Time: {} hours \n'.format(X_test[0][0], X_test[0][0]/float(Y_pred[0]/60), Y_pred[0]/60))
# Out:
# Distance: 42.195 Km, Speed: 9.58948562713284 Km/h, Time: 4.400131731843044 hours

# %%
plt.figure(figsize=(15,4))
plt.scatter(X_train, regr.predict(X_train)/60, label='predicted')
plt.scatter(X_test, Y_pred/60, label='predicted 42km')
plt.scatter(X_train, Y_train/60, label='historical')
plt.plot([0, X_test], [0, Y_pred/60], '--', color='C2')
plt.ylabel('Hours')
plt.xlabel('Kilometers')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# - Dados de Percurso (OK)
# - Dados de Corrida de Lochness tempo geral
# - COmo me categorizo  dentre todos corredores ? (Clustering ?)
# - Prever meu tempo na maratona (regressao basica) (OK)

# %% [markdown]
# ## E como seria meu desempenho comparado a um corredor de elite ?
#
# ### Vocês conhecem Daniel Nascimento ?
# - Brasileiro, recordista sul-americano, primeiro latino-americano com maratona abaixo de 2h9min
#
# ![](./images/samik.png)

# %% [markdown]
# ### Analisando o seu histórico de preparo para Maratona de Seoul 2022 (Janeiro até Abril de 2022)
# - Dados públicos a partir do perfil do Strava do Daniel Nascimento (https://www.strava.com/athletes/86921955)

# %%
session = rpd.read_dir_aggregate('./daniel_runs/adjusted')
#In this session we compute the distance and the distance per position across all workouts
session = session.session.distance()
#compute the speed for each activity
session = session.session.speed(from_distances=True)
#compute the pace for each activity
session = session.session.pace()
#compute the inactivity periods for each activity
session = session.session.only_moving()
summary_daniel = session.session.summarize()
summary_daniel
# Out:
#                               moving_time  mean_speed  max_speed  \
# start
# 2022-02-12 00:00:00+00:00 0 days 01:00:00    5.098612   7.568361
# 2022-02-18 00:00:00+00:00 0 days 00:41:49    3.943658   6.026986
# 2022-02-19 00:00:00+00:00 0 days 01:03:34    5.271218   7.012325
# 2022-02-20 00:00:00+00:00 0 days 01:26:00    3.498662   4.607538
# 2022-02-21 00:00:00+00:00 0 days 01:19:44    3.252885   4.792876
# 2022-02-22 00:00:00+00:00 0 days 00:05:54    5.771621   7.131227
# 2022-02-23 00:00:00+00:00 0 days 00:49:46    3.359324   4.741087
# 2022-02-24 00:00:00+00:00 0 days 02:14:51    4.962103   6.483726
# 2022-02-25 00:00:00+00:00 0 days 01:29:26    2.984316   6.717733
# 2022-02-26 00:00:00+00:00 0 days 01:00:31    4.968786   7.201104
# 2022-02-27 00:00:00+00:00 0 days 00:38:50    4.360039   7.675683
# 2022-02-28 00:00:00+00:00 0 days 01:40:41    3.295220   5.520517
# 2022-03-01 00:00:00+00:00 0 days 00:52:37    3.150240   5.835211
# ...

# %%
summary_daniel['days_diff'] = summary_daniel.index.to_series().diff().dt.days
summary_daniel['total_distance_km'] = summary_daniel['total_distance'] / 1000  #conver meters to kms
summary_daniel['mean_speed_km'] = summary_daniel['mean_speed'] * 3.6 #convert to km/h
summary_daniel['mean_moving_speed'] = summary_daniel['mean_moving_speed'] * 3.6 #convert to km/h
summary_daniel = summary_daniel.assign(Year=summary_daniel.index.year, Month=summary_daniel.index.month, Week=summary_daniel.index.week, Weekday=summary_daniel.index.weekday)
summary_daniel['Year-month'] = pd.to_datetime(summary_daniel[['Year','Month']].assign(day=1)).dt.to_period('M')
summary_daniel['Year-week'] =  summary_daniel.index.strftime('%Y-w%U')
def convert_to_minutes(time_delta_obj):
    return time_delta_obj/datetime.timedelta(minutes=1)

summary_daniel['mean_moving_pace_float'] = summary_daniel['mean_moving_pace'].apply(convert_to_minutes)
summary_daniel['mean_pace_float'] = summary_daniel['mean_pace'].apply(convert_to_minutes)
summary_daniel['speed_all_mean'] = round(summary_daniel.mean_speed_km.mean(),2)

summary_daniel
# Out:
#                               moving_time  mean_speed  max_speed  \
# start
# 2022-02-12 00:00:00+00:00 0 days 01:00:00    5.098612   7.568361
# 2022-02-18 00:00:00+00:00 0 days 00:41:49    3.943658   6.026986
# 2022-02-19 00:00:00+00:00 0 days 01:03:34    5.271218   7.012325
# 2022-02-20 00:00:00+00:00 0 days 01:26:00    3.498662   4.607538
# 2022-02-21 00:00:00+00:00 0 days 01:19:44    3.252885   4.792876
# 2022-02-22 00:00:00+00:00 0 days 00:05:54    5.771621   7.131227
# 2022-02-23 00:00:00+00:00 0 days 00:49:46    3.359324   4.741087
# 2022-02-24 00:00:00+00:00 0 days 02:14:51    4.962103   6.483726
# 2022-02-25 00:00:00+00:00 0 days 01:29:26    2.984316   6.717733
# 2022-02-26 00:00:00+00:00 0 days 01:00:31    4.968786   7.201104
# 2022-02-27 00:00:00+00:00 0 days 00:38:50    4.360039   7.675683
# 2022-02-28 00:00:00+00:00 0 days 01:40:41    3.295220   5.520517
# 2022-03-01 00:00:00+00:00 0 days 00:52:37    3.150240   5.835211
# ...

# %%
plt.figure(figsize=(20,8))


# plot each point again, and its value as a label
plt.scatter(x=summary_daniel.index, y=summary_daniel.mean_speed_km, c=summary_daniel.total_distance_km,edgecolors='none')
# add the legend
#plt.scatter(x=recent_frame.Date.values, y=recent_frame.Speed, c=recent_frame.Kilometers, s=recent_frame.Climb, label=None)
#plt.scatter(x=pd.to_datetime('2017-10-09', format='%Y-%m-%d'), y=X_test[0][0]/float(y_pred[0]/60), c=X_test[0][0], s=X_test[0][1], linewidth=3)
plt.plot(summary_daniel.speed_all_mean, linestyle='dashed', label='média', color='C2')
plt.colorbar(label='Distance')
plt.xlabel('Date')
plt.ylabel('Average Speed')
plt.legend()
plt.show()

# %% [markdown]
# ### Se eu apostasse uma corrida com Daniel , qual seria o resultado ?
#
# - Vamos o utilizar o resultado da regressão linear que construídmos para prever meu tempo nos 42kms.
# - Vamos pegar o seu resultado na prova de Seoul 2022

# %%
import runpandas as rpd
daniel_seoul = rpd.read_file('./daniel_runs/adjusted/strava__6994580246-SEOUL-MARATHON.gpx')
#compute the distance using haversine formula between two consecutive latitude, longitudes observations.
daniel_seoul['distpos']  = daniel_seoul.compute.distance()
#compute the distance cummulative position
daniel_seoul['dist'] = daniel_seoul['distpos'].cumsum()
#conver to km
daniel_seoul['dist_km'] = daniel_seoul['dist'] / 1000
daniel_seoul['dist_km'] = daniel_seoul['dist_km'].fillna(0)
daniel_seoul
# Out:
#                  temp   cad   alt         lon        lat    distpos  \
# time
# 0 days 00:00:00  21.0   NaN  55.4  126.977135  37.573213        NaN
# 0 days 00:00:01  21.0   NaN  55.4  126.977135  37.573213   0.000000
# 0 days 00:00:05  21.0   NaN  55.4  126.977134  37.573102  12.342969
# 0 days 00:00:08  21.0  99.0  55.4  126.977144  37.572921  20.145596
# 0 days 00:00:10  21.0  99.0  55.4  126.977155  37.572805  12.935009
# ...               ...   ...   ...         ...        ...        ...
# 0 days 02:08:47  24.0  84.0  -3.4  127.071901  37.515716   0.000000
# 0 days 02:08:52  24.0  75.0  -3.4  127.071901  37.515716   0.000000
# 0 days 02:09:09  24.0   NaN  -4.0  127.071901  37.515716   0.000000
# 0 days 02:09:18  24.0   NaN  -4.2  127.071901  37.515716   0.000000
# 0 days 02:09:24  24.0   NaN  -4.2  127.071901  37.515716   0.000000
#
#                          dist    dist_km
# time
# 0 days 00:00:00           NaN   0.000000
# 0 days 00:00:01      0.000000   0.000000
# ...

# %%
#usando o modelo de regressão linear para computar para todas as distâncias calculadas previstas por daniel qual seria o meu tempo
Y_pred = regr.predict(daniel_seoul['dist_km'].values.reshape(-1,1))

# %%
#Criando um dataframe contendo os tempos de marcel para cada posicao computada corrida por daniel
marcel_vs_daniel = pd.DataFrame(index= pd.to_timedelta(Y_pred, unit='minutes'), data=daniel_seoul['dist_km'].values, columns=['dist_km'])
marcel_vs_daniel.index.name = 'time'
marcel_vs_daniel
# Out:
#                              dist_km
# time
# 0 days 00:01:36.497220960   0.000000
# 0 days 00:01:36.497220960   0.000000
# 0 days 00:01:41.102681640   0.012343
# 0 days 00:01:48.619491720   0.032489
# 0 days 00:01:53.445856920   0.045424
# ...                              ...
# 0 days 04:26:36.661852680  42.613594
# 0 days 04:26:36.661852680  42.613594
# 0 days 04:26:36.661852680  42.613594
# 0 days 04:26:36.661852680  42.613594
# 0 days 04:26:36.661852680  42.613594
#
# [2664 rows x 1 columns]

# %%
#Criando um frame mergeado olhando os timestamps iguais aproximaddos contendo os tempos x distancias de marcel e daniel
merged_frame = pd.merge_asof(marcel_vs_daniel, daniel_seoul, on='time')[['time', 'dist_km_x', 'dist_km_y']]
merged_frame.index = merged_frame.time
merged_frame = merged_frame.drop(['time'], axis=1)
merged_frame = merged_frame.rename({'dist_km_x': 'marcel', 'dist_km_y': 'daniel'}, axis=1)
merged_frame = merged_frame[~merged_frame.index.duplicated(keep='first')]
merged_frame
# Out:
#                               marcel     daniel
# time
# 0 days 00:01:36.497220960   0.000000   0.536400
# 0 days 00:01:41.102681640   0.012343   0.576318
# 0 days 00:01:48.619491720   0.032489   0.618284
# 0 days 00:01:53.445856920   0.045424   0.651280
# 0 days 00:01:55.852477140   0.051873   0.657065
# ...                              ...        ...
# 0 days 04:26:31.618817700  42.600078  42.613594
# 0 days 04:26:32.170895640  42.601558  42.613594
# 0 days 04:26:32.937558179  42.603613  42.613594
# 0 days 04:26:34.382139060  42.607484  42.613594
# 0 days 04:26:36.661852680  42.613594  42.613594
#
# [2645 rows x 2 columns]

# %% [markdown]
# ### Calculando para cada posição do Daniel, qual tempo estaria minha posicao

# %%
import matplotlib.pyplot as plt
series = merged_frame.iloc[1000]
series
# Out:
# marcel    16.164607
# daniel    34.684808
# Name: 0 days 01:42:07.903798980, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(4, 2.5), dpi=144)
colors = plt.cm.Dark2(range(6))
y = series.index
width = series.values
ax.barh(y=y, width=width, color=colors);

# %%
def niceaxes(ax):
    ax.set_facecolor('.8')
    ax.tick_params(labelsize=8, length=0)
    ax.grid(True, axis='x', color='white')
    ax.set_axisbelow(True)
    [spine.set_visible(False) for spine in ax.spines.values()]

niceaxes(ax)
fig

# %%
fig, ax_array = plt.subplots(nrows=1, ncols=3, figsize=(7, 2.5), dpi=144, tight_layout=True)
index = merged_frame.index.values[:3]
for ax, idx in zip(ax_array, index):
    s = merged_frame.loc[idx]
    y = merged_frame.loc[idx].rank(method='first').values
    ax.barh(y=s.index, width=y, color=colors)
    ax.set_title(str(pd.to_timedelta(idx)).replace('0 days', ''), fontsize='smaller')
    niceaxes(ax)

# %%
sample_merged_frame = merged_frame.sample(frac=0.3).sort_index()
sample_merged_frame
# Out:
#                               marcel     daniel
# time
# 0 days 00:02:05.130513840   0.076739   0.725716
# 0 days 00:02:11.692013880   0.094325   0.749140
# 0 days 00:02:24.368947200   0.128300   0.826446
# 0 days 00:02:44.590756680   0.182496   0.951450
# 0 days 00:02:46.745271300   0.188270   0.951450
# ...                              ...        ...
# 0 days 04:26:00.056902860  42.515490  42.613594
# 0 days 04:26:11.203915140  42.545365  42.613594
# 0 days 04:26:12.537732     42.548940  42.613594
# 0 days 04:26:32.170895640  42.601558  42.613594
# 0 days 04:26:36.661852680  42.613594  42.613594
#
# [794 rows x 2 columns]

# %%
from matplotlib.animation import FuncAnimation

def init():
    ax.clear()
    niceaxes(ax)
    #ax.set_ylim(.2, 6.8)

def update(i):
    for bar in ax.containers:
        bar.remove()
    s = sample_merged_frame.iloc[i]
    y = sample_merged_frame.iloc[i].values
    ax.barh(y=s.index, width=y, color=colors, tick_label=sample_merged_frame.columns)
    time_str = str(sample_merged_frame.index[i]).replace('0 days', '')
    ax.set_title(f'Corrida Marcel x Daniel Nascimento - {time_str}', fontsize='smaller')

fig = plt.Figure(figsize=(4, 2.5), dpi=150)
ax = fig.add_subplot()
anim = FuncAnimation(fig=fig, func=update, init_func=init, frames=len(sample_merged_frame),
                     interval=100, repeat=False)

# %%
from IPython.display import Video
anim.save('test.mp4')
Video("test.mp4")
# Out:
# <video src="test.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Conclusões
#
# - Corrida e ou qualquer atividade física é de extrema importância para nossa saúde física, mental e longevidade.
#
# - Correr de verdade é muito mais que simplesmente por um tênis e um short/camiseta.
#
# - Há uma imensidão de dados gerados por sensores e dispositivos conectados a esportes físicos. Grandes oportunidades para estudos, projetos e negócios.
#
# - Em breve digo se eu consegui realmente completar a maratona em 4h40min!

# %% [markdown]
# ## Trabalhos Futuros
# - Runpandas nativo com suporte a gráficos, análise de dados de corridas e percursos.
#
# - Realizar o primeiro estudo de análise de todas as corridas da São Silvestre, Brazil.
#
# - Paralelismo para desempenho com maior volume de dados com [Dask](https://www.dask.org/).

# %% [markdown]
# - Issues abertas em https://github.com/corriporai/runpandas/issues
# - Documentação em https://www.runpandas.run/

# %% [markdown]
# # Referências
#
# [1] https://blog.concannon.tech/tech-talk/gps-activity-data-file-types/
#
# [2] https://medium.com/decathlontechnology/gpx-tcx-fit-how-to-choose-the-best-file-extension-for-sport-activity-transfer-403487337c04
#
# [3] https://www.rhoderunner.com/run-club-blog/running-metrics
#
# [4] https://www.physigo.org/running-metrics-explained
#
# [5] https://heartzones.com/wp-content/uploads/2016/03/hz-white-paper.pdf
#
# [6] https://www.phoenix.gov/firesite/Documents/d_041762.pdf
#
# [7] https://corriporai.github.io/pandasrunner/general/jupyter/training/metrics/features/2021/05/20/trainingzones.html

# %% [markdown]
# # Vamos correr pessoal ? Obrigado!
